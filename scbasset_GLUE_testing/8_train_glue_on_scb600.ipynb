# %%
import anndata as ad 
import os
import pandas as pd 
import scglue 
import scanpy as sc 
#generate rna
path='2024-02-25-19_54_56'

#generate rna 
# rna = ad.read_h5ad('/home/ubuntu0/scBasset/Chen-2019-RNA.h5ad')
# rna.layers["counts"] = rna.X.copy()

# #select high expressive genes as in the tutorial the number 2000
# sc.pp.highly_variable_genes(rna, n_top_genes=60000, flavor="seurat_v3")

# sc.pp.normalize_total(rna)
# sc.pp.log1p(rna)
# sc.pp.scale(rna)
# sc.tl.pca(rna, n_comps=100, svd_solver="auto")

# sc.pp.neighbors(rna, metric="cosine")
# sc.tl.umap(rna)
# sc.pl.umap(rna,color='cell_type')

# scglue.data.get_gene_annotation(
#     rna, gtf="/home/ubuntu0/GLUE/evaluation/workflow/scripts/gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz",
#     gtf_by="gene_name"
# )
# rna=ad.read_h5ad('unfiltered_rna.h5ad')
atacl=[]
for i in range(8):
    atacl.append(ad.read_h5ad(path+'data/embedatac%s.h5ad'%str(i)))

# %%
#get atac0,atac1,atac2

guidancel=[]
for i in range(8):
    atac=atacl[i]
    scglue.data.lsi(atac, n_components=100, n_iter=15)#enable lsi embedding
    split = atac.var_names.str.split(r"[:-]")
    atac.var["chrom"] = atac.var['chr']
    atac.var["chromStart"] = atac.var['start']
    atac.var["chromEnd"] = atac.var['end']
    guidance=scglue.genomics.rna_anchored_guidance_graph(rna, atac)
    atac.obsm['proj']=pd.read_csv(path+'scb_embedding/scb'+str(i)+'.csv',index_col=0).values #add scbasset embedding
    guidancel.append(guidance)
    atac.write_h5ad(path+'data/embedatac'+str(i)+'.h5ad')#contain lsi and scb
    
sc.pp.subsample(rna,n_obs=4000,random_state=42) #filter rna here
# Out:
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 56968.16it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 56140.26it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 56162.63it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 57045.45it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 55699.13it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 55394.02it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:00<00:00, 57130.46it/s]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scglue/num.py:289: RuntimeWarning: divide by zero encountered in divide
#   idf = X.shape[0] / X.sum(axis=0)
# window_graph: 100%|███████████████████████████████████████████████████████████████████████████████████████| 28930/28930 [00:01<00:00, 21076.77it/s]

# %%
rna.write_h5ad(path+'data/filtered_rna600ep.h5ad')

# %%
rna=ad.read_h5ad(path+'data/filtered_rna600ep.h5ad')

# %%
import scglue
from itertools import chain
import networkx as nx 
def train_glue(rna,atac,input_representation,guidance):
     
    #pca rna and lsi atac
    scglue.models.configure_dataset(rna,'NB',use_highly_variable=True,use_layer='counts',use_rep='X_pca')

    scglue.models.configure_dataset(atac,'NB',use_highly_variable=True,use_rep=input_representation)

    guidance_hvf=guidance.subgraph(chain(rna.var.query('highly_variable').index,atac.var.query('highly_variable').index)).copy()

    glue=scglue.models.fit_SCGLUE({'rna':rna,'atac':atac},guidance_hvf,fit_kws={'directory':'glue'})
    return glue,guidance_hvf

# %%
import os 
os.makedirs(path+'glue')

# %%
import warnings 
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd 

def metric_ari(atac,rep):
    import scib
    sc.pp.neighbors(atac, use_rep=rep)
    scib.me.cluster_optimal_resolution(atac, cluster_key="cluster", label_key="cell_type")
    return scib.me.ari(atac, cluster_key="cluster", label_key="cell_type")

def metric_nmi(atac,rep):
    import scib
    scib.me.cluster_optimal_resolution(atac, cluster_key="cluster", label_key="cell_type")
    return scib.me.nmi(atac, cluster_key="cluster", label_key="cell_type")

def run_scib2(atac,proj):
    import scib
    import pandas as pd
    atac.obs['cell_type']=atac.obs['cell_type'].astype('category')
    atac.obs['batch']=0
    atac.obs['batch']=atac.obs['batch'].astype('category')
    out={}
    out.update({'ari': metric_ari(atac,proj),
           'nmi': metric_nmi(atac,proj),
            'isolated_labels_aws':scib.me.isolated_labels_asw(atac, batch_key="batch", label_key="cell_type", embed=proj),
            'isolated_labels_f1':scib.me.isolated_labels_f1(atac, batch_key="batch", label_key="cell_type",embed='X_glue'),
            'silhouette':scib.me.silhouette(atac, label_key="cell_type", embed="X_glue"),
            'clisi':scib.me.clisi_graph(atac, label_key="cell_type", type_='embed',use_rep=proj)
           })
    out = {k:[v] for k,v in out.items()} 
    out = pd.DataFrame(out)
    out.loc[:,'bio']=out.mean(1)
    return out

def run_scib(atac,proj):
    import scib
    clisi=False
    ilisi=False
    graph_connect=False
    hvg=False
    atac.obs['cell_type']=atac.obs['cell_type'].astype('category')
    atac.obs['batch']=0
    atac.obs['batch']=atac.obs['batch'].astype('category')
    out=scib.metrics.metrics(atac, atac, batch_key='batch', label_key='cell_type', embed=proj, cluster_key='cluster', cluster_nmi=None, ari_=True, nmi_=True, nmi_method='arithmetic', nmi_dir=None, silhouette_=True, si_metric='euclidean', pcr_=True, cell_cycle_=False, organism='human', hvg_score_=hvg, isolated_labels_=True, isolated_labels_f1_=False, isolated_labels_asw_=True, n_isolated=True, graph_conn_=graph_connect, trajectory_=False, kBET_=False, lisi_graph_=False, ilisi_=ilisi, clisi_=clisi, subsample=0.5, n_cores=1, type_=None, verbose=False)
    out.loc['clisi',:]=scib.me.clisi_graph(atac, label_key="cell_type", type_='embed',use_rep=proj)
    return out

def metric_res(dflist,data_namelist):
    gmetrics=pd.concat(dflist,axis='rows')
    gmetrics=gmetrics.set_axis(data_namelist,axis='rows')

    # bio=gmetrics.loc[['NMI_cluster/label','ARI_cluster/label','ASW_label','cell_cycle_conservation','isolated_label_F1','isolated_label_silhouette','hvg_overlap','trajectory'],:,]
    # bio=bio.T
    # bio=bio.drop(columns=['hvg_overlap','trajectory','cell_cycle_conservation'])
    # #bio mean 
    # bio['bio']=bio.mean(axis=1)
    bio_style=gmetrics.style.background_gradient(cmap = 'Blues')
    return gmetrics,bio_style


def plot_dx(dx_lsi,dx_scb,save_pth):

    fig,ax=plt.subplots(1,2,figsize=(20,6),gridspec_kw={'wspace':0.9})
    sub=sns.lineplot(x='n_meta',y='consistency',data=dx_lsi,ax=ax[0],label='baseline').axhline(y=0.05,c='darkred',ls='--')
    ax[0].set_title('baseline consistency score')
    ax[0].get_legend().remove()
    sns.lineplot(x='n_meta',y='consistency',data=dx_scb,ax=ax[1],label='scglue with scbasset embedding(input)').axhline(y=0.05,c='darkred',ls='--')
    ax[1].set_title('scbasset+scglue consistency score')
    ax[1].get_legend().remove()

    plt.savefig(save_pth)
    
def plot_dx_together(dx_lsi,dx_scb,save_pth):
    dx_list=[]
    dx_list.append(dx_lsi.T)
    dx_list.append(dx_scb.T)
    dx_metrics = pd.concat(dx_list,axis='rows')
    dx_metrics = dx_metrics.T
    dx_metrics = dx_metrics.iloc[:,[0,1,3]]
    dx_metrics = dx_metrics.set_axis(['n_meta cells','baseline consistency','scbasset+scglue consistency'],axis='columns')
    dx_metrics = dx_metrics.set_index('n_meta cells')
    ax=dx_metrics.plot(figsize=(8,6))
    ax.set_ylabel('consistency')
    ax.set_xlabel('n-meta cells')
    plt.title('scglue consistency score metrics')
    plt.savefig(save_pth)

# %%
os.makedirs(path+'hvfguidance',exist_ok=True)

# %%
bio_result=[]
name_list=[]
for i in range(8):# to train glue embedding
    atac=atacl[i]
    guidance=guidancel[i]
    
    glue_scb,guidance_hvf_scb=train_glue(rna,atac,'proj',guidance)
    glue_scb.save(path+'glue/scb'+str(i)+'.dill')
    dx_scb = scglue.models.integration_consistency(glue_scb, {"rna": rna, "atac": atac}, guidance_hvf_scb)
    nx.write_graphml(guidance_hvf_scb,path+'hvfguidance/'+'hvfscb'+str(i))
    
    glue_lsi,guidance_hvf_lsi=train_glue(rna,atac,'X_lsi',guidance)
    glue_lsi.save(path+'glue/lsi'+str(i)+'.dill')
    nx.write_graphml(guidance_hvf_lsi,path+'hvfguidance/'+'hvflsi'+str(i))
    dx_lsi = scglue.models.integration_consistency(glue_lsi, {"rna": rna, "atac": atac}, guidance_hvf_lsi)
    plot_dx_together(dx_lsi,dx_scb,'dx600ep'+str(i)+'.png')
# Out:
# [INFO] fit_SCGLUE: Pretraining SCGLUE model...
# [INFO] autodevice: Using GPU 0 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 50133
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/pretrain"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.444, 'g_kl': 0.002, 'g_elbo': 0.446, 'x_rna_nll': 0.115, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.691, 'vae_loss': 0.192, 'gen_loss': 0.157}, val={'g_nll': 0.44, 'g_kl': 0.002, 'g_elbo': 0.442, 'x_rna_nll': 0.116, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.118, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.694, 'vae_loss': 0.19, 'gen_loss': 0.156}, 4.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.421, 'g_kl': 0.002, 'g_elbo': 0.424, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.692, 'vae_loss': 0.186, 'gen_loss': 0.151}, val={'g_nll': 0.42, 'g_kl': 0.002, 'g_elbo': 0.422, 'x_rna_nll': 0.116, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.694, 'vae_loss': 0.188, 'gen_loss': 0.154}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.413, 'g_kl': 0.003, 'g_elbo': 0.416, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.184, 'gen_loss': 0.149}, val={'g_nll': 0.412, 'g_kl': 0.003, 'g_elbo': 0.415, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.694, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.408, 'g_kl': 0.003, 'g_elbo': 0.411, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.182, 'gen_loss': 0.148}, val={'g_nll': 0.408, 'g_kl': 0.003, 'g_elbo': 0.411, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.694, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.406, 'g_kl': 0.003, 'g_elbo': 0.409, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.407, 'g_kl': 0.003, 'g_elbo': 0.41, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.694, 'vae_loss': 0.185, 'gen_loss': 0.15}, 4.5s elapsed
# Epoch 00072: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00072: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.691, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.5s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.185, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.186, 'gen_loss': 0.151}, 3.6s elapsed
# Epoch 00105: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00105: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.692, 'vae_loss': 0.187, 'gen_loss': 0.153}, 3.5s elapsed
# 2024-02-27 21:37:35,549 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "87"...
# [INFO] EarlyStopping: Restoring checkpoint "87"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (16, 10)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 50133
# [INFO] SCGLUEModel: Setting `align_burnin` = 72
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/fine-tune"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.696, 'vae_loss': 0.181, 'gen_loss': 0.147}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.691, 'vae_loss': 0.182, 'gen_loss': 0.147}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.399, 'g_kl': 0.003, 'g_elbo': 0.402, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.695, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.398, 'g_kl': 0.003, 'g_elbo': 0.401, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.679, 'vae_loss': 0.183, 'gen_loss': 0.149}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.395, 'g_kl': 0.003, 'g_elbo': 0.398, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.689, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.395, 'g_kl': 0.003, 'g_elbo': 0.398, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.689, 'vae_loss': 0.184, 'gen_loss': 0.15}, 3.9s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.392, 'g_kl': 0.003, 'g_elbo': 0.395, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.393, 'g_kl': 0.003, 'g_elbo': 0.396, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.678, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.391, 'g_kl': 0.003, 'g_elbo': 0.394, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.393, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.683, 'vae_loss': 0.183, 'gen_loss': 0.148}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.389, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.696, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.393, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.672, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.682, 'vae_loss': 0.183, 'gen_loss': 0.149}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.183, 'gen_loss': 0.148}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.39, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.686, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.39, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.686, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.69, 'vae_loss': 0.185, 'gen_loss': 0.151}, 3.6s elapsed
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.687, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.4s elapsed
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.694, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.673, 'vae_loss': 0.185, 'gen_loss': 0.152}, 3.9s elapsed
# [INFO] SCGLUETrainer: [Epoch 130] train={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.686, 'vae_loss': 0.184, 'gen_loss': 0.149}, 4.0s elapsed
# Epoch 00133: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00133: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 140] train={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.382, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.691, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.678, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 150] train={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.69, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.686, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.0s elapsed
# Epoch 00152: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00152: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 160] train={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.382, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.382, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.666, 'vae_loss': 0.185, 'gen_loss': 0.151}, 4.2s elapsed
# 2024-02-27 21:49:54,703 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] integration_consistency: Using layer "counts" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "atac"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "rna"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "atac"
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 10 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 20 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 50 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 100 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 200 common metacells...
# [WARNING] configure_dataset: `configure_dataset` has already been called. Previous configuration will be overwritten!
# [WARNING] configure_dataset: `configure_dataset` has already been called. Previous configuration will be overwritten!
# [INFO] fit_SCGLUE: Pretraining SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 50133
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/pretrain"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.445, 'g_kl': 0.002, 'g_elbo': 0.447, 'x_rna_nll': 0.115, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.691, 'vae_loss': 0.192, 'gen_loss': 0.157}, val={'g_nll': 0.441, 'g_kl': 0.002, 'g_elbo': 0.443, 'x_rna_nll': 0.116, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.118, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.694, 'vae_loss': 0.191, 'gen_loss': 0.156}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.422, 'g_kl': 0.002, 'g_elbo': 0.425, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.692, 'vae_loss': 0.186, 'gen_loss': 0.151}, val={'g_nll': 0.42, 'g_kl': 0.003, 'g_elbo': 0.423, 'x_rna_nll': 0.116, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.695, 'vae_loss': 0.188, 'gen_loss': 0.154}, 4.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.414, 'g_kl': 0.003, 'g_elbo': 0.417, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.184, 'gen_loss': 0.149}, val={'g_nll': 0.414, 'g_kl': 0.003, 'g_elbo': 0.416, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.695, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.409, 'g_kl': 0.003, 'g_elbo': 0.412, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.182, 'gen_loss': 0.148}, val={'g_nll': 0.409, 'g_kl': 0.003, 'g_elbo': 0.412, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.695, 'vae_loss': 0.186, 'gen_loss': 0.151}, 3.8s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.407, 'g_kl': 0.003, 'g_elbo': 0.41, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.407, 'g_kl': 0.003, 'g_elbo': 0.41, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.407, 'g_kl': 0.003, 'g_elbo': 0.41, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.2s elapsed
# Epoch 00060: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00060: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.185, 'gen_loss': 0.15}, 4.1s elapsed
# Epoch 00079: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00079: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.406, 'g_kl': 0.003, 'g_elbo': 0.409, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.185, 'gen_loss': 0.15}, 3.9s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.3s elapsed
# Epoch 00105: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00105: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.0s elapsed
# 2024-02-27 21:59:49,143 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "87"...
# [INFO] EarlyStopping: Restoring checkpoint "87"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (13, 10)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 50133
# [INFO] SCGLUEModel: Setting `align_burnin` = 72
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/fine-tune"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.695, 'vae_loss': 0.181, 'gen_loss': 0.147}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.684, 'vae_loss': 0.182, 'gen_loss': 0.148}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.689, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.677, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.4, 'g_kl': 0.003, 'g_elbo': 0.403, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.69, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.399, 'g_kl': 0.003, 'g_elbo': 0.402, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.5s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.396, 'g_kl': 0.003, 'g_elbo': 0.399, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.396, 'g_kl': 0.003, 'g_elbo': 0.399, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.694, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.394, 'g_kl': 0.003, 'g_elbo': 0.397, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.695, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.393, 'g_kl': 0.003, 'g_elbo': 0.396, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.68, 'vae_loss': 0.183, 'gen_loss': 0.149}, 4.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.391, 'g_kl': 0.003, 'g_elbo': 0.394, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.393, 'g_kl': 0.003, 'g_elbo': 0.396, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.691, 'vae_loss': 0.184, 'gen_loss': 0.149}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.394, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.687, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.393, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.685, 'vae_loss': 0.183, 'gen_loss': 0.149}, 3.8s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.389, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.689, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.389, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.687, 'vae_loss': 0.183, 'gen_loss': 0.148}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.684, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.678, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.688, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.39, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.698, 'vae_loss': 0.186, 'gen_loss': 0.151}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.386, 'g_kl': 0.003, 'g_elbo': 0.389, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.3s elapsed
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.385, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.691, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.675, 'vae_loss': 0.185, 'gen_loss': 0.152}, 4.0s elapsed
# [INFO] SCGLUETrainer: [Epoch 130] train={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.694, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.687, 'vae_loss': 0.184, 'gen_loss': 0.149}, 4.1s elapsed
# Epoch 00133: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00133: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 140] train={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.382, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.689, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.69, 'vae_loss': 0.184, 'gen_loss': 0.15}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 150] train={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.687, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.382, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.688, 'vae_loss': 0.184, 'gen_loss': 0.15}, 4.2s elapsed
# Epoch 00152: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00152: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 160] train={'g_nll': 0.379, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.695, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.383, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.682, 'vae_loss': 0.185, 'gen_loss': 0.151}, 3.9s elapsed
# 2024-02-27 22:11:49,266 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] integration_consistency: Using layer "counts" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "atac"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "rna"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "atac"
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 10 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 20 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 50 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 100 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 200 common metacells...
# [WARNING] configure_dataset: `configure_dataset` has already been called. Previous configuration will be overwritten!
# [INFO] fit_SCGLUE: Pretraining SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 49723
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/pretrain"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.442, 'g_kl': 0.002, 'g_elbo': 0.444, 'x_rna_nll': 0.115, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.691, 'vae_loss': 0.191, 'gen_loss': 0.156}, val={'g_nll': 0.439, 'g_kl': 0.002, 'g_elbo': 0.441, 'x_rna_nll': 0.117, 'x_rna_kl': 0.002, 'x_rna_elbo': 0.118, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.695, 'vae_loss': 0.192, 'gen_loss': 0.158}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.42, 'g_kl': 0.002, 'g_elbo': 0.422, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.185, 'gen_loss': 0.151}, val={'g_nll': 0.419, 'g_kl': 0.002, 'g_elbo': 0.422, 'x_rna_nll': 0.116, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.693, 'vae_loss': 0.191, 'gen_loss': 0.156}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.413, 'g_kl': 0.003, 'g_elbo': 0.416, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.183, 'gen_loss': 0.148}, val={'g_nll': 0.413, 'g_kl': 0.003, 'g_elbo': 0.415, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.694, 'vae_loss': 0.189, 'gen_loss': 0.154}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.408, 'g_kl': 0.003, 'g_elbo': 0.411, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.182, 'gen_loss': 0.148}, val={'g_nll': 0.408, 'g_kl': 0.003, 'g_elbo': 0.411, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.694, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.693, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.3s elapsed
# Epoch 00071: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00071: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.402, 'g_kl': 0.003, 'g_elbo': 0.405, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.693, 'vae_loss': 0.188, 'gen_loss': 0.154}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.692, 'vae_loss': 0.187, 'gen_loss': 0.153}, 3.8s elapsed
# Epoch 00090: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00090: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.4, 'g_kl': 0.003, 'g_elbo': 0.403, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.691, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.1s elapsed
# Epoch 00109: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00109: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.4, 'g_kl': 0.003, 'g_elbo': 0.403, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.0s elapsed
# 2024-02-27 22:21:43,574 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "111"...
# [INFO] EarlyStopping: Restoring checkpoint "111"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (14, 9)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 49723
# [INFO] SCGLUEModel: Setting `align_burnin` = 72
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/fine-tune"
# ...
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.406, 'g_kl': 0.003, 'g_elbo': 0.409, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.053, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.054, 'dsc_loss': 0.692, 'vae_loss': 0.181, 'gen_loss': 0.146}, val={'g_nll': 0.406, 'g_kl': 0.003, 'g_elbo': 0.409, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.693, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.693, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.2s elapsed
# Epoch 00071: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00071: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.154}, 3.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.691, 'vae_loss': 0.187, 'gen_loss': 0.153}, 4.3s elapsed
# Epoch 00090: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00090: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.693, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.3s elapsed
# Epoch 00109: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00109: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.117, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.153}, 4.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.114, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.692, 'vae_loss': 0.188, 'gen_loss': 0.153}, 3.8s elapsed
# 2024-02-28 02:54:52,876 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "111"...
# [INFO] EarlyStopping: Restoring checkpoint "111"...
# [INFO] fit_SCGLUE: Estimating balancing weight...
# [INFO] estimate_balancing_weight: Clustering cells...
# [INFO] estimate_balancing_weight: Matching clusters...
# [INFO] estimate_balancing_weight: Matching array shape = (14, 9)...
# [INFO] estimate_balancing_weight: Estimating balancing weight...
# [INFO] fit_SCGLUE: Fine-tuning SCGLUE model...
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] SCGLUEModel: Setting `graph_batch_size` = 49723
# [INFO] SCGLUEModel: Setting `align_burnin` = 72
# [INFO] SCGLUEModel: Setting `max_epochs` = 427
# [INFO] SCGLUEModel: Setting `patience` = 36
# [INFO] SCGLUEModel: Setting `reduce_lr_patience` = 18
# [INFO] SCGLUETrainer: Using training directory: "glue/fine-tune"
# [INFO] SCGLUETrainer: [Epoch 10] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.689, 'vae_loss': 0.18, 'gen_loss': 0.146}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.11, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.718, 'vae_loss': 0.182, 'gen_loss': 0.147}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 20] train={'g_nll': 0.404, 'g_kl': 0.003, 'g_elbo': 0.407, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.179, 'gen_loss': 0.145}, val={'g_nll': 0.405, 'g_kl': 0.003, 'g_elbo': 0.408, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.716, 'vae_loss': 0.184, 'gen_loss': 0.148}, 4.1s elapsed
# [INFO] SCGLUETrainer: [Epoch 30] train={'g_nll': 0.403, 'g_kl': 0.003, 'g_elbo': 0.406, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.111, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.684, 'vae_loss': 0.18, 'gen_loss': 0.145}, val={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.699, 'vae_loss': 0.185, 'gen_loss': 0.151}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 40] train={'g_nll': 0.4, 'g_kl': 0.003, 'g_elbo': 0.403, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.689, 'vae_loss': 0.179, 'gen_loss': 0.144}, val={'g_nll': 0.401, 'g_kl': 0.003, 'g_elbo': 0.404, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.746, 'vae_loss': 0.185, 'gen_loss': 0.148}, 4.5s elapsed
# [INFO] SCGLUETrainer: [Epoch 50] train={'g_nll': 0.396, 'g_kl': 0.003, 'g_elbo': 0.4, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.687, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.396, 'g_kl': 0.003, 'g_elbo': 0.399, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.718, 'vae_loss': 0.184, 'gen_loss': 0.148}, 4.4s elapsed
# [INFO] SCGLUETrainer: [Epoch 60] train={'g_nll': 0.393, 'g_kl': 0.003, 'g_elbo': 0.396, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.687, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.392, 'g_kl': 0.003, 'g_elbo': 0.395, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.734, 'vae_loss': 0.186, 'gen_loss': 0.149}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 70] train={'g_nll': 0.391, 'g_kl': 0.003, 'g_elbo': 0.394, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.053, 'dsc_loss': 0.692, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.391, 'g_kl': 0.003, 'g_elbo': 0.394, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.727, 'vae_loss': 0.184, 'gen_loss': 0.148}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 80] train={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.393, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.052, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.689, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.39, 'g_kl': 0.003, 'g_elbo': 0.393, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.71, 'vae_loss': 0.184, 'gen_loss': 0.149}, 4.3s elapsed
# [INFO] SCGLUETrainer: [Epoch 90] train={'g_nll': 0.389, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.109, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.681, 'vae_loss': 0.178, 'gen_loss': 0.144}, val={'g_nll': 0.389, 'g_kl': 0.003, 'g_elbo': 0.392, 'x_rna_nll': 0.111, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.112, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.734, 'vae_loss': 0.184, 'gen_loss': 0.147}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 100] train={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.689, 'vae_loss': 0.178, 'gen_loss': 0.143}, val={'g_nll': 0.388, 'g_kl': 0.003, 'g_elbo': 0.391, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.727, 'vae_loss': 0.186, 'gen_loss': 0.15}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 110] train={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.39, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.686, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.387, 'g_kl': 0.003, 'g_elbo': 0.39, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.735, 'vae_loss': 0.186, 'gen_loss': 0.149}, 4.5s elapsed
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] SCGLUETrainer: [Epoch 120] train={'g_nll': 0.383, 'g_kl': 0.003, 'g_elbo': 0.386, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.686, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.382, 'g_kl': 0.003, 'g_elbo': 0.386, 'x_rna_nll': 0.115, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.116, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.7, 'vae_loss': 0.187, 'gen_loss': 0.152}, 4.2s elapsed
# [INFO] SCGLUETrainer: [Epoch 130] train={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.385, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.692, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.115, 'x_atac_nll': 0.056, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.057, 'dsc_loss': 0.709, 'vae_loss': 0.187, 'gen_loss': 0.151}, 4.2s elapsed
# Epoch 00137: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00137: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] SCGLUETrainer: [Epoch 140] train={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.109, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.684, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.112, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.113, 'x_atac_nll': 0.054, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.055, 'dsc_loss': 0.717, 'vae_loss': 0.184, 'gen_loss': 0.148}, 3.7s elapsed
# [INFO] SCGLUETrainer: [Epoch 150] train={'g_nll': 0.381, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.108, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.11, 'x_atac_nll': 0.051, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.052, 'dsc_loss': 0.688, 'vae_loss': 0.177, 'gen_loss': 0.143}, val={'g_nll': 0.38, 'g_kl': 0.003, 'g_elbo': 0.384, 'x_rna_nll': 0.113, 'x_rna_kl': 0.001, 'x_rna_elbo': 0.114, 'x_atac_nll': 0.055, 'x_atac_kl': 0.001, 'x_atac_elbo': 0.056, 'dsc_loss': 0.721, 'vae_loss': 0.185, 'gen_loss': 0.149}, 4.1s elapsed
# 2024-02-28 03:06:17,880 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] EarlyStopping: Restoring checkpoint "137"...
# [INFO] integration_consistency: Using layer "counts" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "rna"
# [INFO] integration_consistency: Selecting aggregation "sum" for modality "atac"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "rna"
# [INFO] integration_consistency: Selecting log-norm preprocessing for modality "atac"
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 10 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 20 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 50 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 100 common metacells...
# [INFO] get_metacells: Clustering metacells...
# [WARNING] get_metacells: `faiss` is not installed, using `sklearn` instead... This might be slow with a large number of cells. Consider installing `faiss` following the guide from https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# [INFO] get_metacells: Aggregating metacells...
# [INFO] metacell_corr: Computing correlation on 200 common metacells...

# %%
#scib check

df_list=[]
name_list=[]
for i in range(8):
    atac=atacl[i]
    glue_scb=scglue.models.load_model(path+'glue/scb'+str(i)+'.dill')
    glue_lsi=scglue.models.load_model(path+'glue/lsi'+str(i)+'.dill')
    atac.obsm['X_glue']=glue_lsi.encode_data('atac',atac)
    df1=run_scib2(atac,'X_glue')
    atac.obsm['X_glue']=glue_scb.encode_data('atac',atac)
    df2=run_scib2(atac,'X_glue')
    df_list.append(df1)
    df_list.append(df2)
    name_list.append('d'+str(i)+'lsi')
    name_list.append('d'+str(i)+'scbasset')
# Out:
# resolution: 0.1, nmi: 0.20846775507809534
# resolution: 0.2, nmi: 0.4133558465301415
# resolution: 0.3, nmi: 0.4825372308827788
# resolution: 0.4, nmi: 0.49529827564822787
# resolution: 0.5, nmi: 0.5006168112263283
# resolution: 0.6, nmi: 0.5012382453223033
# resolution: 0.7, nmi: 0.5030894041635398
# resolution: 0.8, nmi: 0.5151706991073233
# resolution: 0.9, nmi: 0.5196430934805802
# resolution: 1.0, nmi: 0.5170699030821365
# resolution: 1.1, nmi: 0.4840093466819549
# resolution: 1.2, nmi: 0.47794098965764537
# resolution: 1.3, nmi: 0.48408177156101523
# resolution: 1.4, nmi: 0.47939059812513307
# resolution: 1.5, nmi: 0.47241889052560637
# resolution: 1.6, nmi: 0.47086028622208514
# resolution: 1.7, nmi: 0.45555036143179883
# resolution: 1.8, nmi: 0.4451993947017257
# resolution: 1.9, nmi: 0.4517250737552092
# resolution: 2.0, nmi: 0.4433169904606228
# optimised clustering against cell_type
# optimal cluster resolution: 0.9
# optimal score: 0.5196430934805802
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20846775507809534
# resolution: 0.2, nmi: 0.4133558465301415
# resolution: 0.3, nmi: 0.4825372308827788
# resolution: 0.4, nmi: 0.49529827564822787
# resolution: 0.5, nmi: 0.5006168112263283
# resolution: 0.6, nmi: 0.5012382453223033
# resolution: 0.7, nmi: 0.5030894041635398
# resolution: 0.8, nmi: 0.5151706991073233
# resolution: 0.9, nmi: 0.5196430934805802
# resolution: 1.0, nmi: 0.5170699030821365
# resolution: 1.1, nmi: 0.4840093466819549
# resolution: 1.2, nmi: 0.47794098965764537
# resolution: 1.3, nmi: 0.48408177156101523
# resolution: 1.4, nmi: 0.47939059812513307
# resolution: 1.5, nmi: 0.47241889052560637
# resolution: 1.6, nmi: 0.47086028622208514
# resolution: 1.7, nmi: 0.45555036143179883
# resolution: 1.8, nmi: 0.4451993947017257
# resolution: 1.9, nmi: 0.4517250737552092
# resolution: 2.0, nmi: 0.4433169904606228
# optimised clustering against cell_type
# optimal cluster resolution: 0.9
# optimal score: 0.5196430934805802
# isolated labels: no more than 1 batches per label
# Ast: 0.5505844429135323
# Clau: 0.5038611302152276
# E2Rasgrf2: 0.49159599747508764
# E3Rmst: 0.4976559258066118
# E3Rorb: 0.5004435800656211
# E4Il1rapl2: 0.4936849093064666
# E4Thsd7a: 0.5352500155568123
# E5Galnt14: 0.4893060773611069
# E5Parm1: 0.5476776398718357
# E5Sulf1: 0.48216343484818935
# E5Tshz2: 0.4991497015580535
# E6Tle4: 0.5190895386040211
# Endo: 0.4538973458111286
# InN: 0.4886025907471776
# InP: 0.5252008363604546
# InS: 0.5150886746123433
# InV: 0.46951461769640446
# Mic: 0.4266272559762001
# OPC: 0.47608652524650097
# OliI: 0.4929025494493544
# OliM: 0.4781749565154314
# Peri: 0.45358311012387276
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8323699421965318
# Compute neighbors on rep X_glue
# Clau: 0.27986348122866894
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.830799411476214
# Compute neighbors on rep X_glue
# E3Rmst: 0.15517241379310343
# Compute neighbors on rep X_glue
# E3Rorb: 0.7385257301808066
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.41707717569786534
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.6039387308533917
# Compute neighbors on rep X_glue
# E5Galnt14: 0.39938556067588327
# Compute neighbors on rep X_glue
# E5Parm1: 0.6642335766423358
# Compute neighbors on rep X_glue
# E5Sulf1: 0.17824074074074076
# Compute neighbors on rep X_glue
# E5Tshz2: 0.07142857142857142
# Compute neighbors on rep X_glue
# E6Tle4: 0.8035714285714285
# Compute neighbors on rep X_glue
# Endo: 0.05405405405405406
# Compute neighbors on rep X_glue
# InN: 0.14193548387096774
# Compute neighbors on rep X_glue
# InP: 0.6212534059945505
# Compute neighbors on rep X_glue
# InS: 0.43582089552238806
# Compute neighbors on rep X_glue
# InV: 0.20820189274447948
# Compute neighbors on rep X_glue
# Mic: 0.1111111111111111
# Compute neighbors on rep X_glue
# OPC: 0.3063063063063063
# Compute neighbors on rep X_glue
# OliI: 0.10810810810810811
# Compute neighbors on rep X_glue
# OliM: 0.5824561403508772
# Compute neighbors on rep X_glue
# Peri: 0.019230769230769232
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2270659355306931
# resolution: 0.2, nmi: 0.48251600830449654
# resolution: 0.3, nmi: 0.4778651391088935
# resolution: 0.4, nmi: 0.4858230098442907
# resolution: 0.5, nmi: 0.4966195829470361
# resolution: 0.6, nmi: 0.5016924553461468
# resolution: 0.7, nmi: 0.5064885827911773
# resolution: 0.8, nmi: 0.505166307033715
# resolution: 0.9, nmi: 0.5019793577700856
# resolution: 1.0, nmi: 0.488318881709106
# resolution: 1.1, nmi: 0.4865808561517877
# resolution: 1.2, nmi: 0.4789649637046498
# resolution: 1.3, nmi: 0.47735060792681466
# resolution: 1.4, nmi: 0.48045834059009085
# resolution: 1.5, nmi: 0.4644461863812423
# resolution: 1.6, nmi: 0.4651006392442248
# resolution: 1.7, nmi: 0.46508775762135873
# resolution: 1.8, nmi: 0.4552250837147411
# resolution: 1.9, nmi: 0.4519287292763177
# resolution: 2.0, nmi: 0.45071843538665607
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5064885827911773
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2270659355306931
# resolution: 0.2, nmi: 0.48251600830449654
# resolution: 0.3, nmi: 0.4778651391088935
# resolution: 0.4, nmi: 0.4858230098442907
# resolution: 0.5, nmi: 0.4966195829470361
# resolution: 0.6, nmi: 0.5016924553461468
# resolution: 0.7, nmi: 0.5064885827911773
# resolution: 0.8, nmi: 0.505166307033715
# resolution: 0.9, nmi: 0.5019793577700856
# resolution: 1.0, nmi: 0.488318881709106
# resolution: 1.1, nmi: 0.4865808561517877
# resolution: 1.2, nmi: 0.4789649637046498
# resolution: 1.3, nmi: 0.47735060792681466
# resolution: 1.4, nmi: 0.48045834059009085
# resolution: 1.5, nmi: 0.4644461863812423
# resolution: 1.6, nmi: 0.4651006392442248
# resolution: 1.7, nmi: 0.46508775762135873
# resolution: 1.8, nmi: 0.4552250837147411
# resolution: 1.9, nmi: 0.4519287292763177
# resolution: 2.0, nmi: 0.45071843538665607
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5064885827911773
# isolated labels: no more than 1 batches per label
# Ast: 0.5153731629252434
# Clau: 0.5124639524146914
# E2Rasgrf2: 0.503801861545071
# E3Rmst: 0.4893337283283472
# E3Rorb: 0.49956477593514137
# E4Il1rapl2: 0.5006740042590536
# E4Thsd7a: 0.548900805413723
# E5Galnt14: 0.4867969835177064
# E5Parm1: 0.5467251352965832
# E5Sulf1: 0.48291608691215515
# E5Tshz2: 0.5033347406424582
# E6Tle4: 0.5151731595396996
# Endo: 0.42551853507757187
# InN: 0.48552616965025663
# InP: 0.5261666793376207
# InS: 0.4941326645202935
# InV: 0.4644507169723511
# Mic: 0.4390134923160076
# OPC: 0.49070945754647255
# OliI: 0.49213693011552095
# OliM: 0.4580664336681366
# Peri: 0.4493224322795868
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7403846153846153
# Compute neighbors on rep X_glue
# Clau: 0.3466666666666667
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8303797468354429
# Compute neighbors on rep X_glue
# E3Rmst: 0.10526315789473684
# Compute neighbors on rep X_glue
# E3Rorb: 0.7291960507757406
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.3602941176470589
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5890909090909091
# Compute neighbors on rep X_glue
# E5Galnt14: 0.3575581395348837
# Compute neighbors on rep X_glue
# E5Parm1: 0.5858585858585857
# Compute neighbors on rep X_glue
# E5Sulf1: 0.19967793880837362
# Compute neighbors on rep X_glue
# E5Tshz2: 0.07086614173228346
# Compute neighbors on rep X_glue
# E6Tle4: 0.7861952861952861
# Compute neighbors on rep X_glue
# Endo: 0.04347826086956522
# Compute neighbors on rep X_glue
# InN: 0.17094017094017094
# Compute neighbors on rep X_glue
# InP: 0.5639810426540285
# Compute neighbors on rep X_glue
# InS: 0.391644908616188
# Compute neighbors on rep X_glue
# InV: 0.2437673130193906
# Compute neighbors on rep X_glue
# Mic: 0.09056603773584905
# Compute neighbors on rep X_glue
# OPC: 0.2536231884057971
# Compute neighbors on rep X_glue
# OliI: 0.1142857142857143
# Compute neighbors on rep X_glue
# OliM: 0.6915887850467289
# Compute neighbors on rep X_glue
# Peri: 0.01639344262295082
# resolution: 0.1, nmi: 0.24964500961713246
# resolution: 0.2, nmi: 0.40349683258603586
# resolution: 0.3, nmi: 0.4629275866898919
# resolution: 0.4, nmi: 0.4800363099125397
# resolution: 0.5, nmi: 0.47343030405181014
# resolution: 0.6, nmi: 0.5006352802270991
# resolution: 0.7, nmi: 0.5081161937338355
# resolution: 0.8, nmi: 0.5106708189395296
# resolution: 0.9, nmi: 0.4954025527340359
# resolution: 1.0, nmi: 0.4957740833225726
# resolution: 1.1, nmi: 0.5025388779194551
# resolution: 1.2, nmi: 0.486409023277151
# resolution: 1.3, nmi: 0.4648509038937906
# resolution: 1.4, nmi: 0.4593188702871563
# resolution: 1.5, nmi: 0.4558591478185852
# resolution: 1.6, nmi: 0.45571780329689643
# resolution: 1.7, nmi: 0.45308163974742377
# resolution: 1.8, nmi: 0.4459544014248344
# resolution: 1.9, nmi: 0.450039258917432
# resolution: 2.0, nmi: 0.4441982167499153
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5106708189395296
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.24964500961713246
# resolution: 0.2, nmi: 0.40349683258603586
# resolution: 0.3, nmi: 0.4629275866898919
# resolution: 0.4, nmi: 0.4800363099125397
# resolution: 0.5, nmi: 0.47343030405181014
# resolution: 0.6, nmi: 0.5006352802270991
# resolution: 0.7, nmi: 0.5081161937338355
# resolution: 0.8, nmi: 0.5106708189395296
# resolution: 0.9, nmi: 0.4954025527340359
# resolution: 1.0, nmi: 0.4957740833225726
# resolution: 1.1, nmi: 0.5025388779194551
# resolution: 1.2, nmi: 0.486409023277151
# resolution: 1.3, nmi: 0.4648509038937906
# resolution: 1.4, nmi: 0.4593188702871563
# resolution: 1.5, nmi: 0.4558591478185852
# resolution: 1.6, nmi: 0.45571780329689643
# resolution: 1.7, nmi: 0.45308163974742377
# resolution: 1.8, nmi: 0.4459544014248344
# resolution: 1.9, nmi: 0.450039258917432
# resolution: 2.0, nmi: 0.4441982167499153
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5106708189395296
# isolated labels: no more than 1 batches per label
# Ast: 0.5365027524530888
# Clau: 0.49814376630820334
# E2Rasgrf2: 0.5069235856644809
# E3Rmst: 0.4995067988638766
# E3Rorb: 0.49744270415976644
# E4Il1rapl2: 0.4875148795545101
# E4Thsd7a: 0.5409256815910339
# E5Galnt14: 0.4914201330393553
# E5Parm1: 0.5837304592132568
# E5Sulf1: 0.47981693409383297
# E5Tshz2: 0.5092214355245233
# E6Tle4: 0.5216653477400541
# Endo: 0.4570758529007435
# InN: 0.47211572155356407
# InP: 0.5196590106934309
# InS: 0.5020278778392822
# InV: 0.4662296660244465
# Mic: 0.40715909749269485
# OPC: 0.46785780042409897
# OliI: 0.49638180807232857
# OliM: 0.42020219564437866
# Peri: 0.410320520401001
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8217522658610271
# Compute neighbors on rep X_glue
# Clau: 0.16621983914209115
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8227848101265822
# Compute neighbors on rep X_glue
# E3Rmst: 0.1688888888888889
# Compute neighbors on rep X_glue
# E3Rorb: 0.7322993931220498
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.3694390715667311
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5892857142857143
# Compute neighbors on rep X_glue
# E5Galnt14: 0.42586750788643535
# Compute neighbors on rep X_glue
# E5Parm1: 0.8294314381270903
# Compute neighbors on rep X_glue
# E5Sulf1: 0.1950354609929078
# Compute neighbors on rep X_glue
# E5Tshz2: 0.19178082191780824
# Compute neighbors on rep X_glue
# E6Tle4: 0.8148774302620457
# Compute neighbors on rep X_glue
# Endo: 0.03389830508474577
# Compute neighbors on rep X_glue
# InN: 0.17094017094017094
# Compute neighbors on rep X_glue
# InP: 0.6243902439024391
# Compute neighbors on rep X_glue
# InS: 0.4274406332453826
# Compute neighbors on rep X_glue
# InV: 0.17563739376770537
# Compute neighbors on rep X_glue
# Mic: 0.050955414012738856
# Compute neighbors on rep X_glue
# OPC: 0.4432432432432432
# Compute neighbors on rep X_glue
# OliI: 0.1258741258741259
# Compute neighbors on rep X_glue
# OliM: 0.5
# Compute neighbors on rep X_glue
# Peri: 0.09090909090909091
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2220004827379041
# resolution: 0.2, nmi: 0.38968270811260464
# resolution: 0.3, nmi: 0.4513448698231736
# resolution: 0.4, nmi: 0.4509905195638865
# resolution: 0.5, nmi: 0.4791674793629167
# resolution: 0.6, nmi: 0.47989981368714113
# resolution: 0.7, nmi: 0.47382136116272267
# resolution: 0.8, nmi: 0.46078371269566004
# resolution: 0.9, nmi: 0.456061854984942
# resolution: 1.0, nmi: 0.4574917832417269
# resolution: 1.1, nmi: 0.44903001026043854
# resolution: 1.2, nmi: 0.4510409750668884
# resolution: 1.3, nmi: 0.4483206276286116
# resolution: 1.4, nmi: 0.4305911420914697
# resolution: 1.5, nmi: 0.4301218220222462
# resolution: 1.6, nmi: 0.4291802156844635
# resolution: 1.7, nmi: 0.4207330527638708
# resolution: 1.8, nmi: 0.42343041805250353
# resolution: 1.9, nmi: 0.41720671915789315
# resolution: 2.0, nmi: 0.41909006842952334
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.47989981368714113
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2220004827379041
# resolution: 0.2, nmi: 0.38968270811260464
# resolution: 0.3, nmi: 0.4513448698231736
# resolution: 0.4, nmi: 0.4509905195638865
# resolution: 0.5, nmi: 0.4791674793629167
# resolution: 0.6, nmi: 0.47989981368714113
# resolution: 0.7, nmi: 0.47382136116272267
# resolution: 0.8, nmi: 0.46078371269566004
# resolution: 0.9, nmi: 0.456061854984942
# resolution: 1.0, nmi: 0.4574917832417269
# resolution: 1.1, nmi: 0.44903001026043854
# resolution: 1.2, nmi: 0.4510409750668884
# resolution: 1.3, nmi: 0.4483206276286116
# resolution: 1.4, nmi: 0.4305911420914697
# resolution: 1.5, nmi: 0.4301218220222462
# resolution: 1.6, nmi: 0.4291802156844635
# resolution: 1.7, nmi: 0.4207330527638708
# resolution: 1.8, nmi: 0.42343041805250353
# resolution: 1.9, nmi: 0.41720671915789315
# resolution: 2.0, nmi: 0.41909006842952334
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.47989981368714113
# isolated labels: no more than 1 batches per label
# Ast: 0.49868591770064086
# Clau: 0.4753028377890587
# E2Rasgrf2: 0.5236994866281748
# E3Rmst: 0.4931950196623802
# E3Rorb: 0.4996313785959501
# E4Il1rapl2: 0.5007245023152791
# E4Thsd7a: 0.5391422770917416
# E5Galnt14: 0.49938303971430287
# E5Parm1: 0.5643882751464844
# E5Sulf1: 0.4784434624016285
# E5Tshz2: 0.5109238941222429
# E6Tle4: 0.5220149736851454
# Endo: 0.43963100016117096
# InN: 0.46077563241124153
# InP: 0.514309810474515
# InS: 0.5003250661538914
# InV: 0.4581237994134426
# Mic: 0.40896423906087875
# OPC: 0.4715185072273016
# OliI: 0.5075047267600894
# OliM: 0.41505465656518936
# Peri: 0.3938593864440918
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7041420118343195
# Compute neighbors on rep X_glue
# Clau: 0.2580645161290323
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8288376655223149
# Compute neighbors on rep X_glue
# E3Rmst: 0.13714285714285715
# Compute neighbors on rep X_glue
# E3Rorb: 0.6747376916868442
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.3606082548877625
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5119047619047619
# Compute neighbors on rep X_glue
# E5Galnt14: 0.38541666666666663
# Compute neighbors on rep X_glue
# E5Parm1: 0.7674418604651162
# Compute neighbors on rep X_glue
# E5Sulf1: 0.27564102564102566
# Compute neighbors on rep X_glue
# E5Tshz2: 0.15730337078651685
# Compute neighbors on rep X_glue
# E6Tle4: 0.7918149466192171
# Compute neighbors on rep X_glue
# Endo: 0.03252032520325203
# Compute neighbors on rep X_glue
# InN: 0.11564625850340136
# Compute neighbors on rep X_glue
# InP: 0.6799999999999999
# Compute neighbors on rep X_glue
# InS: 0.4491017964071856
# Compute neighbors on rep X_glue
# InV: 0.13888888888888887
# Compute neighbors on rep X_glue
# Mic: 0.07453416149068323
# Compute neighbors on rep X_glue
# OPC: 0.2608695652173913
# Compute neighbors on rep X_glue
# OliI: 0.10884353741496598
# Compute neighbors on rep X_glue
# OliM: 0.411522633744856
# Compute neighbors on rep X_glue
# Peri: 0.021276595744680854
# resolution: 0.1, nmi: 0.20101169065622942
# resolution: 0.2, nmi: 0.40381923986555784
# resolution: 0.3, nmi: 0.4809612804197318
# resolution: 0.4, nmi: 0.47950848648788197
# resolution: 0.5, nmi: 0.504786219244944
# resolution: 0.6, nmi: 0.5090048708691152
# resolution: 0.7, nmi: 0.5124966873599749
# resolution: 0.8, nmi: 0.5067859945469472
# resolution: 0.9, nmi: 0.5046833819834871
# resolution: 1.0, nmi: 0.5061942548038663
# resolution: 1.1, nmi: 0.4979702572403374
# resolution: 1.2, nmi: 0.480893352575625
# resolution: 1.3, nmi: 0.47040296862748004
# resolution: 1.4, nmi: 0.47262548358310563
# resolution: 1.5, nmi: 0.4618574002639351
# resolution: 1.6, nmi: 0.4511512691512296
# resolution: 1.7, nmi: 0.4533421367597354
# resolution: 1.8, nmi: 0.4455688123187063
# resolution: 1.9, nmi: 0.4448930090864075
# resolution: 2.0, nmi: 0.4362557579920496
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5124966873599749
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20101169065622942
# resolution: 0.2, nmi: 0.40381923986555784
# resolution: 0.3, nmi: 0.4809612804197318
# resolution: 0.4, nmi: 0.47950848648788197
# resolution: 0.5, nmi: 0.504786219244944
# resolution: 0.6, nmi: 0.5090048708691152
# resolution: 0.7, nmi: 0.5124966873599749
# resolution: 0.8, nmi: 0.5067859945469472
# resolution: 0.9, nmi: 0.5046833819834871
# resolution: 1.0, nmi: 0.5061942548038663
# resolution: 1.1, nmi: 0.4979702572403374
# resolution: 1.2, nmi: 0.480893352575625
# resolution: 1.3, nmi: 0.47040296862748004
# resolution: 1.4, nmi: 0.47262548358310563
# resolution: 1.5, nmi: 0.4618574002639351
# resolution: 1.6, nmi: 0.4511512691512296
# resolution: 1.7, nmi: 0.4533421367597354
# resolution: 1.8, nmi: 0.4455688123187063
# resolution: 1.9, nmi: 0.4448930090864075
# resolution: 2.0, nmi: 0.4362557579920496
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5124966873599749
# isolated labels: no more than 1 batches per label
# Ast: 0.5381610877811909
# Clau: 0.48731557559221983
# E2Rasgrf2: 0.5059480438940227
# E3Rmst: 0.4990216735750437
# E3Rorb: 0.49555268744006753
# E4Il1rapl2: 0.4922929937019944
# E4Thsd7a: 0.5442464910447598
# E5Galnt14: 0.4963660843204707
# E5Parm1: 0.5799882709980011
# E5Sulf1: 0.48450382612645626
# E5Tshz2: 0.49468795163556933
# E6Tle4: 0.5200527124106884
# Endo: 0.45497166365385056
# InN: 0.4680902026593685
# InP: 0.530889518558979
# InS: 0.4956354647874832
# InV: 0.49061865359544754
# Mic: 0.4104307293891907
# OPC: 0.48127453215420246
# OliI: 0.484770935960114
# OliM: 0.4264857992529869
# Peri: 0.40983278304338455
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8315217391304347
# Compute neighbors on rep X_glue
# Clau: 0.16115702479338842
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8241469816272966
# Compute neighbors on rep X_glue
# E3Rmst: 0.22222222222222224
# Compute neighbors on rep X_glue
# E3Rorb: 0.7204529370134466
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.45054945054945056
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.576530612244898
# Compute neighbors on rep X_glue
# E5Galnt14: 0.4154727793696275
# Compute neighbors on rep X_glue
# E5Parm1: 0.8290909090909091
# Compute neighbors on rep X_glue
# E5Sulf1: 0.19622641509433963
# Compute neighbors on rep X_glue
# E5Tshz2: 0.14285714285714288
# Compute neighbors on rep X_glue
# E6Tle4: 0.8159457167090755
# Compute neighbors on rep X_glue
# Endo: 0.023809523809523808
# Compute neighbors on rep X_glue
# InN: 0.14067278287461774
# Compute neighbors on rep X_glue
# InP: 0.625
# Compute neighbors on rep X_glue
# InS: 0.4501424501424501
# Compute neighbors on rep X_glue
# InV: 0.15584415584415584
# Compute neighbors on rep X_glue
# Mic: 0.06106870229007633
# Compute neighbors on rep X_glue
# OPC: 0.40740740740740744
# Compute neighbors on rep X_glue
# OliI: 0.15384615384615383
# Compute neighbors on rep X_glue
# OliM: 0.4694835680751174
# Compute neighbors on rep X_glue
# Peri: 0.015748031496062992
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.25357623151712044
# resolution: 0.2, nmi: 0.39408621666211774
# resolution: 0.3, nmi: 0.4630762306887038
# resolution: 0.4, nmi: 0.4836267403209118
# resolution: 0.5, nmi: 0.49165637126219486
# resolution: 0.6, nmi: 0.47501117864771614
# resolution: 0.7, nmi: 0.4785116746151279
# resolution: 0.8, nmi: 0.47556161000936287
# resolution: 0.9, nmi: 0.4793484535335854
# resolution: 1.0, nmi: 0.4816811514407561
# resolution: 1.1, nmi: 0.46628923951697016
# resolution: 1.2, nmi: 0.4547698776975269
# resolution: 1.3, nmi: 0.46249314245231293
# resolution: 1.4, nmi: 0.45813033843990136
# resolution: 1.5, nmi: 0.4532043308431724
# resolution: 1.6, nmi: 0.44814252143409444
# resolution: 1.7, nmi: 0.4482588390113148
# resolution: 1.8, nmi: 0.44541534252770076
# resolution: 1.9, nmi: 0.43911941849588737
# resolution: 2.0, nmi: 0.4429285258927133
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.49165637126219486
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.25357623151712044
# resolution: 0.2, nmi: 0.39408621666211774
# resolution: 0.3, nmi: 0.4630762306887038
# resolution: 0.4, nmi: 0.4836267403209118
# resolution: 0.5, nmi: 0.49165637126219486
# resolution: 0.6, nmi: 0.47501117864771614
# resolution: 0.7, nmi: 0.4785116746151279
# resolution: 0.8, nmi: 0.47556161000936287
# resolution: 0.9, nmi: 0.4793484535335854
# resolution: 1.0, nmi: 0.4816811514407561
# resolution: 1.1, nmi: 0.46628923951697016
# resolution: 1.2, nmi: 0.4547698776975269
# resolution: 1.3, nmi: 0.46249314245231293
# resolution: 1.4, nmi: 0.45813033843990136
# resolution: 1.5, nmi: 0.4532043308431724
# resolution: 1.6, nmi: 0.44814252143409444
# resolution: 1.7, nmi: 0.4482588390113148
# resolution: 1.8, nmi: 0.44541534252770076
# resolution: 1.9, nmi: 0.43911941849588737
# resolution: 2.0, nmi: 0.4429285258927133
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.49165637126219486
# isolated labels: no more than 1 batches per label
# Ast: 0.5271628722548485
# Clau: 0.4705462772399187
# E2Rasgrf2: 0.5090996837243438
# E3Rmst: 0.4997869087383151
# E3Rorb: 0.4926095618866384
# E4Il1rapl2: 0.49806488398462534
# E4Thsd7a: 0.5353738404810429
# E5Galnt14: 0.49825699580833316
# E5Parm1: 0.5670444443821907
# E5Sulf1: 0.47915126383304596
# E5Tshz2: 0.5108139598742127
# E6Tle4: 0.5191583931446075
# Endo: 0.46069321781396866
# InN: 0.4706201124936342
# InP: 0.5144836967810988
# InS: 0.49674473889172077
# InV: 0.4721966255456209
# Mic: 0.4113805294036865
# OPC: 0.5031100877095014
# OliI: 0.4790259823203087
# OliM: 0.42753346264362335
# Peri: 0.42877545952796936
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7890410958904109
# Compute neighbors on rep X_glue
# Clau: 0.21951219512195125
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8045075943165115
# Compute neighbors on rep X_glue
# E3Rmst: 0.15760266370699225
# Compute neighbors on rep X_glue
# E3Rorb: 0.6958333333333333
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.42961608775137117
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5011086474501109
# Compute neighbors on rep X_glue
# E5Galnt14: 0.3198594024604569
# Compute neighbors on rep X_glue
# E5Parm1: 0.7418181818181819
# Compute neighbors on rep X_glue
# E5Sulf1: 0.1912568306010929
# Compute neighbors on rep X_glue
# E5Tshz2: 0.19999999999999998
# Compute neighbors on rep X_glue
# E6Tle4: 0.8068181818181818
# Compute neighbors on rep X_glue
# Endo: 0.05714285714285715
# Compute neighbors on rep X_glue
# InN: 0.14534883720930236
# Compute neighbors on rep X_glue
# InP: 0.6103286384976525
# Compute neighbors on rep X_glue
# InS: 0.43455497382198954
# Compute neighbors on rep X_glue
# InV: 0.19075144508670522
# Compute neighbors on rep X_glue
# Mic: 0.10909090909090909
# Compute neighbors on rep X_glue
# OPC: 0.2578616352201258
# Compute neighbors on rep X_glue
# OliI: 0.14583333333333334
# Compute neighbors on rep X_glue
# OliM: 0.48704663212435234
# Compute neighbors on rep X_glue
# Peri: 0.017094017094017092
# resolution: 0.1, nmi: 0.20430837465586238
# resolution: 0.2, nmi: 0.4410897800935946
# resolution: 0.3, nmi: 0.4906694100026952
# resolution: 0.4, nmi: 0.4884309596854264
# resolution: 0.5, nmi: 0.48959603077983976
# resolution: 0.6, nmi: 0.5076398626175304
# resolution: 0.7, nmi: 0.5160001455290748
# resolution: 0.8, nmi: 0.5095487353875799
# resolution: 0.9, nmi: 0.5118031076103415
# resolution: 1.0, nmi: 0.5077456757473245
# resolution: 1.1, nmi: 0.5008775038650851
# resolution: 1.2, nmi: 0.4648299406368265
# resolution: 1.3, nmi: 0.47913490004020737
# resolution: 1.4, nmi: 0.46202111552814606
# resolution: 1.5, nmi: 0.4613921729064387
# resolution: 1.6, nmi: 0.4552784679427594
# resolution: 1.7, nmi: 0.447811124431859
# resolution: 1.8, nmi: 0.4442435610573383
# resolution: 1.9, nmi: 0.4365062503586804
# resolution: 2.0, nmi: 0.44133588431847626
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5160001455290748
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20430837465586238
# resolution: 0.2, nmi: 0.4410897800935946
# resolution: 0.3, nmi: 0.4906694100026952
# resolution: 0.4, nmi: 0.4884309596854264
# resolution: 0.5, nmi: 0.48959603077983976
# resolution: 0.6, nmi: 0.5076398626175304
# resolution: 0.7, nmi: 0.5160001455290748
# resolution: 0.8, nmi: 0.5095487353875799
# resolution: 0.9, nmi: 0.5118031076103415
# resolution: 1.0, nmi: 0.5077456757473245
# resolution: 1.1, nmi: 0.5008775038650851
# resolution: 1.2, nmi: 0.4648299406368265
# resolution: 1.3, nmi: 0.47913490004020737
# resolution: 1.4, nmi: 0.46202111552814606
# resolution: 1.5, nmi: 0.4613921729064387
# resolution: 1.6, nmi: 0.4552784679427594
# resolution: 1.7, nmi: 0.447811124431859
# resolution: 1.8, nmi: 0.4442435610573383
# resolution: 1.9, nmi: 0.4365062503586804
# resolution: 2.0, nmi: 0.44133588431847626
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5160001455290748
# isolated labels: no more than 1 batches per label
# Ast: 0.551973469555378
# Clau: 0.5007258352125064
# E2Rasgrf2: 0.5013846026267856
# E3Rmst: 0.4965085976291448
# E3Rorb: 0.4981522695161402
# E4Il1rapl2: 0.4986309923697263
# E4Thsd7a: 0.532085083425045
# E5Galnt14: 0.4888173695653677
# E5Parm1: 0.5823699682950974
# E5Sulf1: 0.48457861226052046
# E5Tshz2: 0.4994365428574383
# E6Tle4: 0.5175310894846916
# Endo: 0.4662070497870445
# InN: 0.4674065113067627
# InP: 0.532378364354372
# InS: 0.5098203886300325
# InV: 0.4712737686932087
# Mic: 0.40273334830999374
# OPC: 0.4657224379479885
# OliI: 0.4980630676727742
# OliM: 0.41965627670288086
# Peri: 0.41040758788585663
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8629737609329446
# Compute neighbors on rep X_glue
# Clau: 0.17846153846153845
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8165618448637316
# Compute neighbors on rep X_glue
# E3Rmst: 0.155467720685112
# Compute neighbors on rep X_glue
# E3Rorb: 0.7007407407407408
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4385593220338983
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.4765784114052954
# Compute neighbors on rep X_glue
# E5Galnt14: 0.35294117647058826
# Compute neighbors on rep X_glue
# E5Parm1: 0.846441947565543
# Compute neighbors on rep X_glue
# E5Sulf1: 0.24102564102564103
# Compute neighbors on rep X_glue
# E5Tshz2: 0.12030075187969923
# Compute neighbors on rep X_glue
# E6Tle4: 0.8247978436657681
# Compute neighbors on rep X_glue
# Endo: 0.024242424242424242
# Compute neighbors on rep X_glue
# InN: 0.17222222222222222
# Compute neighbors on rep X_glue
# InP: 0.5981735159817352
# Compute neighbors on rep X_glue
# InS: 0.4263959390862944
# Compute neighbors on rep X_glue
# InV: 0.18131868131868129
# Compute neighbors on rep X_glue
# Mic: 0.057971014492753624
# Compute neighbors on rep X_glue
# OPC: 0.46341463414634143
# Compute neighbors on rep X_glue
# OliI: 0.12903225806451613
# Compute neighbors on rep X_glue
# OliM: 0.49549549549549554
# Compute neighbors on rep X_glue
# Peri: 0.0303030303030303
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2055024214615842
# resolution: 0.2, nmi: 0.4123664048305547
# resolution: 0.3, nmi: 0.4774020343987996
# resolution: 0.4, nmi: 0.4788822595420595
# resolution: 0.5, nmi: 0.5137706334214526
# resolution: 0.6, nmi: 0.49749456006637394
# resolution: 0.7, nmi: 0.5003522844196545
# resolution: 0.8, nmi: 0.5033781977558209
# resolution: 0.9, nmi: 0.5010033943920084
# resolution: 1.0, nmi: 0.49960904342120893
# resolution: 1.1, nmi: 0.4721990449218155
# resolution: 1.2, nmi: 0.4632730204386536
# resolution: 1.3, nmi: 0.46256658622263425
# resolution: 1.4, nmi: 0.45894667652136634
# resolution: 1.5, nmi: 0.4569934514803116
# resolution: 1.6, nmi: 0.44747309511786665
# resolution: 1.7, nmi: 0.4470400722644156
# resolution: 1.8, nmi: 0.4452800734817374
# resolution: 1.9, nmi: 0.43334979068630264
# resolution: 2.0, nmi: 0.4283815954371404
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.5137706334214526
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2055024214615842
# resolution: 0.2, nmi: 0.4123664048305547
# resolution: 0.3, nmi: 0.4774020343987996
# resolution: 0.4, nmi: 0.4788822595420595
# resolution: 0.5, nmi: 0.5137706334214526
# resolution: 0.6, nmi: 0.49749456006637394
# resolution: 0.7, nmi: 0.5003522844196545
# resolution: 0.8, nmi: 0.5033781977558209
# resolution: 0.9, nmi: 0.5010033943920084
# resolution: 1.0, nmi: 0.49960904342120893
# resolution: 1.1, nmi: 0.4721990449218155
# resolution: 1.2, nmi: 0.4632730204386536
# resolution: 1.3, nmi: 0.46256658622263425
# resolution: 1.4, nmi: 0.45894667652136634
# resolution: 1.5, nmi: 0.4569934514803116
# resolution: 1.6, nmi: 0.44747309511786665
# resolution: 1.7, nmi: 0.4470400722644156
# resolution: 1.8, nmi: 0.4452800734817374
# resolution: 1.9, nmi: 0.43334979068630264
# resolution: 2.0, nmi: 0.4283815954371404
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.5137706334214526
# isolated labels: no more than 1 batches per label
# Ast: 0.5228462219238281
# Clau: 0.48794088512659073
# E2Rasgrf2: 0.5160476639866829
# E3Rmst: 0.4981314392061904
# E3Rorb: 0.49383830465376377
# E4Il1rapl2: 0.49890462670009583
# E4Thsd7a: 0.5437206700444221
# E5Galnt14: 0.4983624519081786
# E5Parm1: 0.5727214440703392
# E5Sulf1: 0.48072440177202225
# E5Tshz2: 0.5080228205770254
# E6Tle4: 0.5277455393224955
# Endo: 0.43222688883543015
# InN: 0.47908578999340534
# InP: 0.5232505816966295
# InS: 0.48564098216593266
# InV: 0.47233970649540424
# Mic: 0.43477681279182434
# OPC: 0.4972889961209148
# OliI: 0.4494737386703491
# OliM: 0.42725321650505066
# Peri: 0.40004733949899673
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7967479674796748
# Compute neighbors on rep X_glue
# Clau: 0.1940928270042194
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8255754475703325
# Compute neighbors on rep X_glue
# E3Rmst: 0.20074349442379186
# Compute neighbors on rep X_glue
# E3Rorb: 0.7263389581804842
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.462015503875969
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5342163355408389
# Compute neighbors on rep X_glue
# E5Galnt14: 0.3708920187793427
# Compute neighbors on rep X_glue
# E5Parm1: 0.8085106382978723
# Compute neighbors on rep X_glue
# E5Sulf1: 0.1863699582753825
# Compute neighbors on rep X_glue
# E5Tshz2: 0.16666666666666669
# Compute neighbors on rep X_glue
# E6Tle4: 0.7966573816155988
# Compute neighbors on rep X_glue
# Endo: 0.04040404040404041
# Compute neighbors on rep X_glue
# InN: 0.13968253968253969
# Compute neighbors on rep X_glue
# InP: 0.65
# Compute neighbors on rep X_glue
# InS: 0.4316939890710383
# Compute neighbors on rep X_glue
# InV: 0.20125786163522014
# Compute neighbors on rep X_glue
# Mic: 0.058823529411764705
# Compute neighbors on rep X_glue
# OPC: 0.3522012578616352
# Compute neighbors on rep X_glue
# OliI: 0.0983606557377049
# Compute neighbors on rep X_glue
# OliM: 0.44954128440366975
# Compute neighbors on rep X_glue
# Peri: 0.020000000000000004
# resolution: 0.1, nmi: 0.19554842036586303
# resolution: 0.2, nmi: 0.387084983342797
# resolution: 0.3, nmi: 0.4982557000923221
# resolution: 0.4, nmi: 0.4988145602047827
# resolution: 0.5, nmi: 0.49060795913311256
# resolution: 0.6, nmi: 0.4879798742710131
# resolution: 0.7, nmi: 0.4998995325311368
# resolution: 0.8, nmi: 0.5106707995930735
# resolution: 0.9, nmi: 0.48603160422314784
# resolution: 1.0, nmi: 0.49595763896131245
# resolution: 1.1, nmi: 0.4737738637562586
# resolution: 1.2, nmi: 0.4756155301379793
# resolution: 1.3, nmi: 0.46236343166950555
# resolution: 1.4, nmi: 0.46456472540645644
# resolution: 1.5, nmi: 0.4549420141495178
# resolution: 1.6, nmi: 0.45171832594873307
# resolution: 1.7, nmi: 0.4500004582957211
# resolution: 1.8, nmi: 0.44749297234879953
# resolution: 1.9, nmi: 0.43663702433159607
# resolution: 2.0, nmi: 0.43997518862682694
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5106707995930735
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.19554842036586303
# resolution: 0.2, nmi: 0.387084983342797
# resolution: 0.3, nmi: 0.4982557000923221
# resolution: 0.4, nmi: 0.4988145602047827
# resolution: 0.5, nmi: 0.49060795913311256
# resolution: 0.6, nmi: 0.4879798742710131
# resolution: 0.7, nmi: 0.4998995325311368
# resolution: 0.8, nmi: 0.5106707995930735
# resolution: 0.9, nmi: 0.48603160422314784
# resolution: 1.0, nmi: 0.49595763896131245
# resolution: 1.1, nmi: 0.4737738637562586
# resolution: 1.2, nmi: 0.4756155301379793
# resolution: 1.3, nmi: 0.46236343166950555
# resolution: 1.4, nmi: 0.46456472540645644
# resolution: 1.5, nmi: 0.4549420141495178
# resolution: 1.6, nmi: 0.45171832594873307
# resolution: 1.7, nmi: 0.4500004582957211
# resolution: 1.8, nmi: 0.44749297234879953
# resolution: 1.9, nmi: 0.43663702433159607
# resolution: 2.0, nmi: 0.43997518862682694
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5106707995930735
# isolated labels: no more than 1 batches per label
# Ast: 0.5363498143851757
# Clau: 0.49939520936459303
# E2Rasgrf2: 0.49859358195681125
# E3Rmst: 0.5039144153706729
# E3Rorb: 0.49534983467310667
# E4Il1rapl2: 0.49575246684253216
# E4Thsd7a: 0.5318559780716896
# E5Galnt14: 0.4872197452932596
# E5Parm1: 0.5729057341814041
# E5Sulf1: 0.48869980592280626
# E5Tshz2: 0.5011262281332165
# E6Tle4: 0.5129432026296854
# Endo: 0.46047627553343773
# InN: 0.4667092002928257
# InP: 0.5251172408461571
# InS: 0.5003464336041361
# InV: 0.4874117635190487
# Mic: 0.4079572260379791
# OPC: 0.4750702567398548
# OliI: 0.4778003878891468
# OliM: 0.4351957216858864
# Peri: 0.43944238498806953
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8264462809917354
# Compute neighbors on rep X_glue
# Clau: 0.19607843137254904
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.7926078028747434
# Compute neighbors on rep X_glue
# E3Rmst: 0.1766109785202864
# Compute neighbors on rep X_glue
# E3Rorb: 0.7246770904146839
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.3936507936507936
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5945945945945946
# Compute neighbors on rep X_glue
# E5Galnt14: 0.36314363143631434
# Compute neighbors on rep X_glue
# E5Parm1: 0.8480565371024734
# Compute neighbors on rep X_glue
# E5Sulf1: 0.24025974025974026
# Compute neighbors on rep X_glue
# E5Tshz2: 0.1596244131455399
# Compute neighbors on rep X_glue
# E6Tle4: 0.8355795148247979
# Compute neighbors on rep X_glue
# Endo: 0.024390243902439022
# Compute neighbors on rep X_glue
# InN: 0.12218649517684886
# Compute neighbors on rep X_glue
# InP: 0.6564102564102564
# Compute neighbors on rep X_glue
# InS: 0.44508670520231214
# Compute neighbors on rep X_glue
# InV: 0.16129032258064516
# Compute neighbors on rep X_glue
# Mic: 0.0746268656716418
# Compute neighbors on rep X_glue
# OPC: 0.4203821656050955
# Compute neighbors on rep X_glue
# OliI: 0.11666666666666667
# Compute neighbors on rep X_glue
# OliM: 0.5
# Compute neighbors on rep X_glue
# Peri: 0.05128205128205127
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.19741920852173542
# resolution: 0.2, nmi: 0.4051805684842943
# resolution: 0.3, nmi: 0.4567775645818997
# resolution: 0.4, nmi: 0.4540410520929185
# resolution: 0.5, nmi: 0.4831697248018546
# resolution: 0.6, nmi: 0.4884494226026658
# resolution: 0.7, nmi: 0.4795611524037096
# resolution: 0.8, nmi: 0.4800612504820309
# resolution: 0.9, nmi: 0.4817222595357973
# resolution: 1.0, nmi: 0.47985202002102356
# resolution: 1.1, nmi: 0.46968166621365576
# resolution: 1.2, nmi: 0.456021014820214
# resolution: 1.3, nmi: 0.45633757327995306
# resolution: 1.4, nmi: 0.4601526145370452
# resolution: 1.5, nmi: 0.45208808602718153
# resolution: 1.6, nmi: 0.44721937859847705
# resolution: 1.7, nmi: 0.45048469551043857
# resolution: 1.8, nmi: 0.4413212965020383
# resolution: 1.9, nmi: 0.4370317619715809
# resolution: 2.0, nmi: 0.43617327991769816
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.4884494226026658
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.19741920852173542
# resolution: 0.2, nmi: 0.4051805684842943
# resolution: 0.3, nmi: 0.4567775645818997
# resolution: 0.4, nmi: 0.4540410520929185
# resolution: 0.5, nmi: 0.4831697248018546
# resolution: 0.6, nmi: 0.4884494226026658
# resolution: 0.7, nmi: 0.4795611524037096
# resolution: 0.8, nmi: 0.4800612504820309
# resolution: 0.9, nmi: 0.4817222595357973
# resolution: 1.0, nmi: 0.47985202002102356
# resolution: 1.1, nmi: 0.46968166621365576
# resolution: 1.2, nmi: 0.456021014820214
# resolution: 1.3, nmi: 0.45633757327995306
# resolution: 1.4, nmi: 0.4601526145370452
# resolution: 1.5, nmi: 0.45208808602718153
# resolution: 1.6, nmi: 0.44721937859847705
# resolution: 1.7, nmi: 0.45048469551043857
# resolution: 1.8, nmi: 0.4413212965020383
# resolution: 1.9, nmi: 0.4370317619715809
# resolution: 2.0, nmi: 0.43617327991769816
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.4884494226026658
# isolated labels: no more than 1 batches per label
# Ast: 0.5207927729934454
# Clau: 0.4893113309517503
# E2Rasgrf2: 0.5189919583499432
# E3Rmst: 0.49155429378151894
# E3Rorb: 0.49791315966285765
# E4Il1rapl2: 0.49444011645391583
# E4Thsd7a: 0.5457995235919952
# E5Galnt14: 0.5004169875755906
# E5Parm1: 0.5623383559286594
# E5Sulf1: 0.4863546062260866
# E5Tshz2: 0.5049131568521261
# E6Tle4: 0.5225724782794714
# Endo: 0.41790519654750824
# InN: 0.45921365916728973
# InP: 0.5187543723732233
# InS: 0.5098415510728955
# InV: 0.4748144969344139
# Mic: 0.4266396537423134
# OPC: 0.47497205063700676
# OliI: 0.4845086634159088
# OliM: 0.4379833899438381
# Peri: 0.4159102812409401
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7701149425287356
# Compute neighbors on rep X_glue
# Clau: 0.22641509433962262
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.7975995635570103
# Compute neighbors on rep X_glue
# E3Rmst: 0.20689655172413793
# Compute neighbors on rep X_glue
# E3Rorb: 0.6907147628590514
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4360902255639098
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5335968379446641
# Compute neighbors on rep X_glue
# E5Galnt14: 0.40242057488653554
# Compute neighbors on rep X_glue
# E5Parm1: 0.6331360946745562
# Compute neighbors on rep X_glue
# E5Sulf1: 0.215929203539823
# Compute neighbors on rep X_glue
# E5Tshz2: 0.10020040080160321
# Compute neighbors on rep X_glue
# E6Tle4: 0.7996604414261459
# Compute neighbors on rep X_glue
# Endo: 0.02649006622516556
# Compute neighbors on rep X_glue
# InN: 0.15434083601286172
# Compute neighbors on rep X_glue
# InP: 0.630272952853598
# Compute neighbors on rep X_glue
# InS: 0.4345403899721448
# Compute neighbors on rep X_glue
# InV: 0.15625000000000003
# Compute neighbors on rep X_glue
# Mic: 0.07017543859649122
# Compute neighbors on rep X_glue
# OPC: 0.31958762886597936
# Compute neighbors on rep X_glue
# OliI: 0.08917197452229297
# Compute neighbors on rep X_glue
# OliM: 0.4357976653696498
# Compute neighbors on rep X_glue
# Peri: 0.01785714285714286
# resolution: 0.1, nmi: 0.20309464842070366
# resolution: 0.2, nmi: 0.36739689532169656
# resolution: 0.3, nmi: 0.4896300310427887
# resolution: 0.4, nmi: 0.47998023942399887
# resolution: 0.5, nmi: 0.5003439636348262
# resolution: 0.6, nmi: 0.5036478023888776
# resolution: 0.7, nmi: 0.5056380722155084
# resolution: 0.8, nmi: 0.5078528501515632
# resolution: 0.9, nmi: 0.5118814471535622
# resolution: 1.0, nmi: 0.5110744526679352
# resolution: 1.1, nmi: 0.5026356105832552
# resolution: 1.2, nmi: 0.4878379846453344
# resolution: 1.3, nmi: 0.4783925455621656
# resolution: 1.4, nmi: 0.4763203744255331
# resolution: 1.5, nmi: 0.4642095918944562
# resolution: 1.6, nmi: 0.4618191027067241
# resolution: 1.7, nmi: 0.4666957116104324
# resolution: 1.8, nmi: 0.4452835977746866
# resolution: 1.9, nmi: 0.4517162497012328
# resolution: 2.0, nmi: 0.4464757676334125
# optimised clustering against cell_type
# optimal cluster resolution: 0.9
# optimal score: 0.5118814471535622
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20309464842070366
# resolution: 0.2, nmi: 0.36739689532169656
# resolution: 0.3, nmi: 0.4896300310427887
# resolution: 0.4, nmi: 0.47998023942399887
# resolution: 0.5, nmi: 0.5003439636348262
# resolution: 0.6, nmi: 0.5036478023888776
# resolution: 0.7, nmi: 0.5056380722155084
# resolution: 0.8, nmi: 0.5078528501515632
# resolution: 0.9, nmi: 0.5118814471535622
# resolution: 1.0, nmi: 0.5110744526679352
# resolution: 1.1, nmi: 0.5026356105832552
# resolution: 1.2, nmi: 0.4878379846453344
# resolution: 1.3, nmi: 0.4783925455621656
# resolution: 1.4, nmi: 0.4763203744255331
# resolution: 1.5, nmi: 0.4642095918944562
# resolution: 1.6, nmi: 0.4618191027067241
# resolution: 1.7, nmi: 0.4666957116104324
# resolution: 1.8, nmi: 0.4452835977746866
# resolution: 1.9, nmi: 0.4517162497012328
# resolution: 2.0, nmi: 0.4464757676334125
# optimised clustering against cell_type
# optimal cluster resolution: 0.9
# optimal score: 0.5118814471535622
# isolated labels: no more than 1 batches per label
# Ast: 0.5352197401225567
# Clau: 0.49538742238655686
# E2Rasgrf2: 0.5033506504260004
# E3Rmst: 0.49922959436662495
# E3Rorb: 0.49606596725061536
# E4Il1rapl2: 0.4928151173517108
# E4Thsd7a: 0.5385009720921516
# E5Galnt14: 0.4955221815034747
# E5Parm1: 0.5807338804006577
# E5Sulf1: 0.49159396439790726
# E5Tshz2: 0.4942261166870594
# E6Tle4: 0.5097301378846169
# Endo: 0.4607769623398781
# InN: 0.46795856207609177
# InP: 0.5253307670354843
# InS: 0.5089625651016831
# InV: 0.4662167839705944
# Mic: 0.40766066312789917
# OPC: 0.4709958378225565
# OliI: 0.49612462520599365
# OliM: 0.43103306740522385
# Peri: 0.40234851092100143
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8047337278106509
# Compute neighbors on rep X_glue
# Clau: 0.1360544217687075
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8213740458015267
# Compute neighbors on rep X_glue
# E3Rmst: 0.1592505854800937
# Compute neighbors on rep X_glue
# E3Rorb: 0.7446808510638298
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.38737446197991393
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.6039387308533918
# Compute neighbors on rep X_glue
# E5Galnt14: 0.39596469104665827
# Compute neighbors on rep X_glue
# E5Parm1: 0.8571428571428572
# Compute neighbors on rep X_glue
# E5Sulf1: 0.18598382749326148
# Compute neighbors on rep X_glue
# E5Tshz2: 0.09756097560975609
# Compute neighbors on rep X_glue
# E6Tle4: 0.8253119429590018
# Compute neighbors on rep X_glue
# Endo: 0.03508771929824561
# Compute neighbors on rep X_glue
# InN: 0.16066481994459833
# Compute neighbors on rep X_glue
# InP: 0.5863636363636363
# Compute neighbors on rep X_glue
# InS: 0.4231738035264484
# Compute neighbors on rep X_glue
# InV: 0.18181818181818182
# Compute neighbors on rep X_glue
# Mic: 0.05970149253731343
# Compute neighbors on rep X_glue
# OPC: 0.3544303797468354
# Compute neighbors on rep X_glue
# OliI: 0.13333333333333333
# Compute neighbors on rep X_glue
# OliM: 0.48148148148148145
# Compute neighbors on rep X_glue
# Peri: 0.03076923076923077
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20492662508871942
# resolution: 0.2, nmi: 0.3618732521942728
# resolution: 0.3, nmi: 0.46184176036751984
# resolution: 0.4, nmi: 0.4610678849586241
# resolution: 0.5, nmi: 0.47528872455161136
# resolution: 0.6, nmi: 0.489310205829665
# resolution: 0.7, nmi: 0.4855216261269298
# resolution: 0.8, nmi: 0.4811443517027358
# resolution: 0.9, nmi: 0.4826405273464687
# resolution: 1.0, nmi: 0.4782519563048971
# resolution: 1.1, nmi: 0.4849586908907168
# resolution: 1.2, nmi: 0.4480375558826127
# resolution: 1.3, nmi: 0.4457560146807367
# resolution: 1.4, nmi: 0.44392677493508703
# resolution: 1.5, nmi: 0.4396318339955188
# resolution: 1.6, nmi: 0.4357040068908112
# resolution: 1.7, nmi: 0.43017986069107517
# resolution: 1.8, nmi: 0.4274823918323905
# resolution: 1.9, nmi: 0.4227576760079466
# resolution: 2.0, nmi: 0.4259154900062839
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.489310205829665
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20492662508871942
# resolution: 0.2, nmi: 0.3618732521942728
# resolution: 0.3, nmi: 0.46184176036751984
# resolution: 0.4, nmi: 0.4610678849586241
# resolution: 0.5, nmi: 0.47528872455161136
# resolution: 0.6, nmi: 0.489310205829665
# resolution: 0.7, nmi: 0.4855216261269298
# resolution: 0.8, nmi: 0.4811443517027358
# resolution: 0.9, nmi: 0.4826405273464687
# resolution: 1.0, nmi: 0.4782519563048971
# resolution: 1.1, nmi: 0.4849586908907168
# resolution: 1.2, nmi: 0.4480375558826127
# resolution: 1.3, nmi: 0.4457560146807367
# resolution: 1.4, nmi: 0.44392677493508703
# resolution: 1.5, nmi: 0.4396318339955188
# resolution: 1.6, nmi: 0.4357040068908112
# resolution: 1.7, nmi: 0.43017986069107517
# resolution: 1.8, nmi: 0.4274823918323905
# resolution: 1.9, nmi: 0.4227576760079466
# resolution: 2.0, nmi: 0.4259154900062839
# optimised clustering against cell_type
# optimal cluster resolution: 0.6
# optimal score: 0.489310205829665
# isolated labels: no more than 1 batches per label
# Ast: 0.5272632353007793
# Clau: 0.4778146706521511
# E2Rasgrf2: 0.5162990223616362
# E3Rmst: 0.4933178573846817
# E3Rorb: 0.49856714403722435
# E4Il1rapl2: 0.49243488535284996
# E4Thsd7a: 0.5366784706711769
# E5Galnt14: 0.5037729041650891
# E5Parm1: 0.563220389187336
# E5Sulf1: 0.4784335810691118
# E5Tshz2: 0.4997745905566262
# E6Tle4: 0.5231600385159254
# Endo: 0.43435829132795334
# InN: 0.47976159676909447
# InP: 0.5184108465909958
# InS: 0.48098223097622395
# InV: 0.49446835927665234
# Mic: 0.4246090427041054
# OPC: 0.4810998812317848
# OliI: 0.47063650749623775
# OliM: 0.4273504987359047
# Peri: 0.41275568306446075
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.7403846153846154
# Compute neighbors on rep X_glue
# Clau: 0.15315315315315314
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8216328653146127
# Compute neighbors on rep X_glue
# E3Rmst: 0.15286624203821655
# Compute neighbors on rep X_glue
# E3Rorb: 0.7143821742066171
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4280442804428044
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.4796573875802998
# Compute neighbors on rep X_glue
# E5Galnt14: 0.39267886855241263
# Compute neighbors on rep X_glue
# E5Parm1: 0.6833855799373041
# Compute neighbors on rep X_glue
# E5Sulf1: 0.208955223880597
# Compute neighbors on rep X_glue
# E5Tshz2: 0.08633093525179857
# Compute neighbors on rep X_glue
# E6Tle4: 0.7919340054995416
# Compute neighbors on rep X_glue
# Endo: 0.034482758620689655
# Compute neighbors on rep X_glue
# InN: 0.10791366906474821
# Compute neighbors on rep X_glue
# InP: 0.6935483870967742
# Compute neighbors on rep X_glue
# InS: 0.43030303030303035
# Compute neighbors on rep X_glue
# InV: 0.13333333333333333
# Compute neighbors on rep X_glue
# Mic: 0.060606060606060615
# Compute neighbors on rep X_glue
# OPC: 0.2482758620689655
# Compute neighbors on rep X_glue
# OliI: 0.1272727272727273
# Compute neighbors on rep X_glue
# OliM: 0.5192307692307693
# Compute neighbors on rep X_glue
# Peri: 0.019047619047619042
# resolution: 0.1, nmi: 0.12755562976099513
# resolution: 0.2, nmi: 0.4085443919803652
# resolution: 0.3, nmi: 0.4600945327292205
# resolution: 0.4, nmi: 0.49385058842049645
# resolution: 0.5, nmi: 0.5112988145539921
# resolution: 0.6, nmi: 0.5064393714410675
# resolution: 0.7, nmi: 0.49196003540986105
# resolution: 0.8, nmi: 0.49159881775297
# resolution: 0.9, nmi: 0.48552429228342525
# resolution: 1.0, nmi: 0.490311368259849
# resolution: 1.1, nmi: 0.4824905482396604
# resolution: 1.2, nmi: 0.4774441191026892
# resolution: 1.3, nmi: 0.46702243502919033
# resolution: 1.4, nmi: 0.4588074765364761
# resolution: 1.5, nmi: 0.465517172698344
# resolution: 1.6, nmi: 0.460397576496283
# resolution: 1.7, nmi: 0.45680752676277103
# resolution: 1.8, nmi: 0.43841188058748215
# resolution: 1.9, nmi: 0.4410804375322663
# resolution: 2.0, nmi: 0.43843564533153406
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.5112988145539921
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.12755562976099513
# resolution: 0.2, nmi: 0.4085443919803652
# resolution: 0.3, nmi: 0.4600945327292205
# resolution: 0.4, nmi: 0.49385058842049645
# resolution: 0.5, nmi: 0.5112988145539921
# resolution: 0.6, nmi: 0.5064393714410675
# resolution: 0.7, nmi: 0.49196003540986105
# resolution: 0.8, nmi: 0.49159881775297
# resolution: 0.9, nmi: 0.48552429228342525
# resolution: 1.0, nmi: 0.490311368259849
# resolution: 1.1, nmi: 0.4824905482396604
# resolution: 1.2, nmi: 0.4774441191026892
# resolution: 1.3, nmi: 0.46702243502919033
# resolution: 1.4, nmi: 0.4588074765364761
# resolution: 1.5, nmi: 0.465517172698344
# resolution: 1.6, nmi: 0.460397576496283
# resolution: 1.7, nmi: 0.45680752676277103
# resolution: 1.8, nmi: 0.43841188058748215
# resolution: 1.9, nmi: 0.4410804375322663
# resolution: 2.0, nmi: 0.43843564533153406
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.5112988145539921
# isolated labels: no more than 1 batches per label
# Ast: 0.5348658449947834
# Clau: 0.49370764987543225
# E2Rasgrf2: 0.4955736668780446
# E3Rmst: 0.5063210278749466
# E3Rorb: 0.4977061317767948
# E4Il1rapl2: 0.49718936905264854
# E4Thsd7a: 0.5338245294988155
# E5Galnt14: 0.49016878847032785
# E5Parm1: 0.5805312469601631
# E5Sulf1: 0.49184675607830286
# E5Tshz2: 0.4996645276551135
# E6Tle4: 0.5117703825235367
# Endo: 0.4575157091021538
# InN: 0.46332649514079094
# InP: 0.5274253059178591
# InS: 0.5154707748442888
# InV: 0.4659535326063633
# Mic: 0.4031585454940796
# OPC: 0.4711807481944561
# OliI: 0.49463546741753817
# OliM: 0.42320337891578674
# Peri: 0.4335799366235733
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8171428571428571
# Compute neighbors on rep X_glue
# Clau: 0.13105413105413105
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8123280132085855
# Compute neighbors on rep X_glue
# E3Rmst: 0.2158273381294964
# Compute neighbors on rep X_glue
# E3Rorb: 0.7157001414427158
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4003378378378379
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.583710407239819
# Compute neighbors on rep X_glue
# E5Galnt14: 0.37740693196405645
# Compute neighbors on rep X_glue
# E5Parm1: 0.8550724637681159
# Compute neighbors on rep X_glue
# E5Sulf1: 0.1890909090909091
# Compute neighbors on rep X_glue
# E5Tshz2: 0.22641509433962265
# Compute neighbors on rep X_glue
# E6Tle4: 0.818499127399651
# Compute neighbors on rep X_glue
# Endo: 0.034334763948497854
# Compute neighbors on rep X_glue
# InN: 0.1723076923076923
# Compute neighbors on rep X_glue
# InP: 0.6564885496183205
# Compute neighbors on rep X_glue
# InS: 0.44
# Compute neighbors on rep X_glue
# InV: 0.16981132075471697
# Compute neighbors on rep X_glue
# Mic: 0.08333333333333334
# Compute neighbors on rep X_glue
# OPC: 0.4
# Compute neighbors on rep X_glue
# OliI: 0.14400000000000002
# Compute neighbors on rep X_glue
# OliM: 0.4933920704845815
# Compute neighbors on rep X_glue
# Peri: 0.02531645569620253
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20007524455118084
# resolution: 0.2, nmi: 0.40259868238002294
# resolution: 0.3, nmi: 0.4692961427266217
# resolution: 0.4, nmi: 0.507841476557295
# resolution: 0.5, nmi: 0.5082703453402679
# resolution: 0.6, nmi: 0.5000282456942283
# resolution: 0.7, nmi: 0.5129382468626901
# resolution: 0.8, nmi: 0.5059731728230221
# resolution: 0.9, nmi: 0.5021771699570331
# resolution: 1.0, nmi: 0.5072863675929614
# resolution: 1.1, nmi: 0.48948666351982173
# resolution: 1.2, nmi: 0.4949849036209956
# resolution: 1.3, nmi: 0.493779223842783
# resolution: 1.4, nmi: 0.48682474677124754
# resolution: 1.5, nmi: 0.473089977260443
# resolution: 1.6, nmi: 0.46689895324769165
# resolution: 1.7, nmi: 0.45225227553722236
# resolution: 1.8, nmi: 0.44821420269369144
# resolution: 1.9, nmi: 0.4504781859844425
# resolution: 2.0, nmi: 0.4494333416804057
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5129382468626901
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20007524455118084
# resolution: 0.2, nmi: 0.40259868238002294
# resolution: 0.3, nmi: 0.4692961427266217
# resolution: 0.4, nmi: 0.507841476557295
# resolution: 0.5, nmi: 0.5082703453402679
# resolution: 0.6, nmi: 0.5000282456942283
# resolution: 0.7, nmi: 0.5129382468626901
# resolution: 0.8, nmi: 0.5059731728230221
# resolution: 0.9, nmi: 0.5021771699570331
# resolution: 1.0, nmi: 0.5072863675929614
# resolution: 1.1, nmi: 0.48948666351982173
# resolution: 1.2, nmi: 0.4949849036209956
# resolution: 1.3, nmi: 0.493779223842783
# resolution: 1.4, nmi: 0.48682474677124754
# resolution: 1.5, nmi: 0.473089977260443
# resolution: 1.6, nmi: 0.46689895324769165
# resolution: 1.7, nmi: 0.45225227553722236
# resolution: 1.8, nmi: 0.44821420269369144
# resolution: 1.9, nmi: 0.4504781859844425
# resolution: 2.0, nmi: 0.4494333416804057
# optimised clustering against cell_type
# optimal cluster resolution: 0.7
# optimal score: 0.5129382468626901
# isolated labels: no more than 1 batches per label
# Ast: 0.525672297924757
# Clau: 0.453824657946825
# E2Rasgrf2: 0.5130669958889484
# E3Rmst: 0.48817723989486694
# E3Rorb: 0.5014628799399361
# E4Il1rapl2: 0.4992398472968489
# E4Thsd7a: 0.5470300018787384
# E5Galnt14: 0.5023685982450843
# E5Parm1: 0.5652258768677711
# E5Sulf1: 0.48014672473073006
# E5Tshz2: 0.518857441842556
# E6Tle4: 0.5219013784080744
# Endo: 0.4480496123433113
# InN: 0.47008039243519306
# InP: 0.5242548435926437
# InS: 0.4863253803923726
# InV: 0.4620688296854496
# Mic: 0.40157400816679
# OPC: 0.48301681876182556
# OliI: 0.46504755318164825
# OliM: 0.4268174320459366
# Peri: 0.40012703835964203
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8044692737430167
# Compute neighbors on rep X_glue
# Clau: 0.13270142180094785
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8242880171950564
# Compute neighbors on rep X_glue
# E3Rmst: 0.18305084745762712
# Compute neighbors on rep X_glue
# E3Rorb: 0.7245590230664857
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4118616144975289
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5807860262008733
# Compute neighbors on rep X_glue
# E5Galnt14: 0.4796238244514106
# Compute neighbors on rep X_glue
# E5Parm1: 0.7382550335570469
# Compute neighbors on rep X_glue
# E5Sulf1: 0.20883534136546186
# Compute neighbors on rep X_glue
# E5Tshz2: 0.08796296296296295
# Compute neighbors on rep X_glue
# E6Tle4: 0.8184187662901825
# Compute neighbors on rep X_glue
# Endo: 0.07692307692307693
# Compute neighbors on rep X_glue
# InN: 0.11764705882352941
# Compute neighbors on rep X_glue
# InP: 0.663101604278075
# Compute neighbors on rep X_glue
# InS: 0.43859649122807026
# Compute neighbors on rep X_glue
# InV: 0.15807560137457044
# Compute neighbors on rep X_glue
# Mic: 0.07246376811594202
# Compute neighbors on rep X_glue
# OPC: 0.36024844720496896
# Compute neighbors on rep X_glue
# OliI: 0.11290322580645161
# Compute neighbors on rep X_glue
# OliM: 0.47747747747747754
# Compute neighbors on rep X_glue
# Peri: 0.01785714285714286
# resolution: 0.1, nmi: 0.20449065767458294
# resolution: 0.2, nmi: 0.40964285522384675
# resolution: 0.3, nmi: 0.4716457835970816
# resolution: 0.4, nmi: 0.5024094017130016
# resolution: 0.5, nmi: 0.5003754296935762
# resolution: 0.6, nmi: 0.5062062245391188
# resolution: 0.7, nmi: 0.5158050838710425
# resolution: 0.8, nmi: 0.5188490603388596
# resolution: 0.9, nmi: 0.51463131492286
# resolution: 1.0, nmi: 0.5010914685635982
# resolution: 1.1, nmi: 0.4896856821895043
# resolution: 1.2, nmi: 0.49057734672219205
# resolution: 1.3, nmi: 0.48414993757256103
# resolution: 1.4, nmi: 0.48285340152000505
# resolution: 1.5, nmi: 0.4727928402126697
# resolution: 1.6, nmi: 0.46071953286523964
# resolution: 1.7, nmi: 0.4632346184675859
# resolution: 1.8, nmi: 0.4581455233533736
# resolution: 1.9, nmi: 0.4582032004915827
# resolution: 2.0, nmi: 0.45455622627849496
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5188490603388596
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.20449065767458294
# resolution: 0.2, nmi: 0.40964285522384675
# resolution: 0.3, nmi: 0.4716457835970816
# resolution: 0.4, nmi: 0.5024094017130016
# resolution: 0.5, nmi: 0.5003754296935762
# resolution: 0.6, nmi: 0.5062062245391188
# resolution: 0.7, nmi: 0.5158050838710425
# resolution: 0.8, nmi: 0.5188490603388596
# resolution: 0.9, nmi: 0.51463131492286
# resolution: 1.0, nmi: 0.5010914685635982
# resolution: 1.1, nmi: 0.4896856821895043
# resolution: 1.2, nmi: 0.49057734672219205
# resolution: 1.3, nmi: 0.48414993757256103
# resolution: 1.4, nmi: 0.48285340152000505
# resolution: 1.5, nmi: 0.4727928402126697
# resolution: 1.6, nmi: 0.46071953286523964
# resolution: 1.7, nmi: 0.4632346184675859
# resolution: 1.8, nmi: 0.4581455233533736
# resolution: 1.9, nmi: 0.4582032004915827
# resolution: 2.0, nmi: 0.45455622627849496
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.5188490603388596
# isolated labels: no more than 1 batches per label
# Ast: 0.5452728308737278
# Clau: 0.49263612320646644
# E2Rasgrf2: 0.5012387012830004
# E3Rmst: 0.5021509944926947
# E3Rorb: 0.4971610992215574
# E4Il1rapl2: 0.49659711634740233
# E4Thsd7a: 0.536876205354929
# E5Galnt14: 0.48667787481099367
# E5Parm1: 0.5782541558146477
# E5Sulf1: 0.4833171535283327
# E5Tshz2: 0.49357897508889437
# E6Tle4: 0.520189480856061
# Endo: 0.46239762008190155
# InN: 0.47397164441645145
# InP: 0.5240834038704634
# InS: 0.5034849217627198
# InV: 0.4838499054312706
# Mic: 0.4062051549553871
# OPC: 0.4630305580794811
# OliI: 0.5083603579550982
# OliM: 0.4220348224043846
# Peri: 0.4211055710911751
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8579710144927536
# Compute neighbors on rep X_glue
# Clau: 0.2260869565217391
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8197054342305738
# Compute neighbors on rep X_glue
# E3Rmst: 0.1609907120743034
# Compute neighbors on rep X_glue
# E3Rorb: 0.7080291970802919
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4635603345280764
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5783132530120483
# Compute neighbors on rep X_glue
# E5Galnt14: 0.34901960784313724
# Compute neighbors on rep X_glue
# E5Parm1: 0.8571428571428572
# Compute neighbors on rep X_glue
# E5Sulf1: 0.20809248554913293
# Compute neighbors on rep X_glue
# E5Tshz2: 0.09615384615384616
# Compute neighbors on rep X_glue
# E6Tle4: 0.8073394495412843
# Compute neighbors on rep X_glue
# Endo: 0.03076923076923077
# Compute neighbors on rep X_glue
# InN: 0.16099071207430338
# Compute neighbors on rep X_glue
# InP: 0.6288416075650118
# Compute neighbors on rep X_glue
# InS: 0.4491978609625668
# Compute neighbors on rep X_glue
# InV: 0.16766467065868262
# Compute neighbors on rep X_glue
# Mic: 0.052980132450331126
# Compute neighbors on rep X_glue
# OPC: 0.425287356321839
# Compute neighbors on rep X_glue
# OliI: 0.13138686131386862
# Compute neighbors on rep X_glue
# OliM: 0.4549356223175966
# Compute neighbors on rep X_glue
# Peri: 0.025974025974025972
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.26705758184900935
# resolution: 0.2, nmi: 0.3843056012304065
# resolution: 0.3, nmi: 0.46102522182776823
# resolution: 0.4, nmi: 0.4558768631494777
# resolution: 0.5, nmi: 0.4677512863026583
# resolution: 0.6, nmi: 0.47883315935592596
# resolution: 0.7, nmi: 0.4879864363608318
# resolution: 0.8, nmi: 0.49099194140201274
# resolution: 0.9, nmi: 0.4909732230131627
# resolution: 1.0, nmi: 0.48544271018968904
# resolution: 1.1, nmi: 0.4606619697784426
# resolution: 1.2, nmi: 0.46152879447549167
# resolution: 1.3, nmi: 0.46468043679606014
# resolution: 1.4, nmi: 0.45806418521385966
# resolution: 1.5, nmi: 0.4543104822257366
# resolution: 1.6, nmi: 0.4423369406789964
# resolution: 1.7, nmi: 0.4411900919823606
# resolution: 1.8, nmi: 0.43448416961844843
# resolution: 1.9, nmi: 0.4398593146450529
# resolution: 2.0, nmi: 0.43629390594047185
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.49099194140201274
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.26705758184900935
# resolution: 0.2, nmi: 0.3843056012304065
# resolution: 0.3, nmi: 0.46102522182776823
# resolution: 0.4, nmi: 0.4558768631494777
# resolution: 0.5, nmi: 0.4677512863026583
# resolution: 0.6, nmi: 0.47883315935592596
# resolution: 0.7, nmi: 0.4879864363608318
# resolution: 0.8, nmi: 0.49099194140201274
# resolution: 0.9, nmi: 0.4909732230131627
# resolution: 1.0, nmi: 0.48544271018968904
# resolution: 1.1, nmi: 0.4606619697784426
# resolution: 1.2, nmi: 0.46152879447549167
# resolution: 1.3, nmi: 0.46468043679606014
# resolution: 1.4, nmi: 0.45806418521385966
# resolution: 1.5, nmi: 0.4543104822257366
# resolution: 1.6, nmi: 0.4423369406789964
# resolution: 1.7, nmi: 0.4411900919823606
# resolution: 1.8, nmi: 0.43448416961844843
# resolution: 1.9, nmi: 0.4398593146450529
# resolution: 2.0, nmi: 0.43629390594047185
# optimised clustering against cell_type
# optimal cluster resolution: 0.8
# optimal score: 0.49099194140201274
# isolated labels: no more than 1 batches per label
# Ast: 0.5409227348864079
# Clau: 0.47775190882384777
# E2Rasgrf2: 0.5217761564999819
# E3Rmst: 0.49429201940074563
# E3Rorb: 0.49465301260352135
# E4Il1rapl2: 0.5016771430382505
# E4Thsd7a: 0.5343735367059708
# E5Galnt14: 0.5014514760114253
# E5Parm1: 0.5330523103475571
# E5Sulf1: 0.4793597385287285
# E5Tshz2: 0.4979602247476578
# E6Tle4: 0.5217108651995659
# Endo: 0.4488792419433594
# InN: 0.4616267569363117
# InP: 0.5097703710198402
# InS: 0.4927100772038102
# InV: 0.4748032335191965
# Mic: 0.41790152341127396
# OPC: 0.48057397082448006
# OliI: 0.49710221914574504
# OliM: 0.43591949343681335
# Peri: 0.40899958461523056
# isolated labels: no more than 1 batches per label
# Compute neighbors on rep X_glue
# Ast: 0.8547008547008548
# Compute neighbors on rep X_glue
# Clau: 0.2619047619047619
# Compute neighbors on rep X_glue
# E2Rasgrf2: 0.8352816153028694
# Compute neighbors on rep X_glue
# E3Rmst: 0.13450292397660818
# Compute neighbors on rep X_glue
# E3Rorb: 0.686473807662236
# Compute neighbors on rep X_glue
# E4Il1rapl2: 0.4099616858237548
# Compute neighbors on rep X_glue
# E4Thsd7a: 0.5193370165745858
# Compute neighbors on rep X_glue
# E5Galnt14: 0.40555555555555556
# Compute neighbors on rep X_glue
# E5Parm1: 0.5673352435530087
# Compute neighbors on rep X_glue
# E5Sulf1: 0.1894150417827298
# Compute neighbors on rep X_glue
# E5Tshz2: 0.0881057268722467
# Compute neighbors on rep X_glue
# E6Tle4: 0.7806563039723662
# Compute neighbors on rep X_glue
# Endo: 0.04166666666666667
# Compute neighbors on rep X_glue
# InN: 0.1377245508982036
# Compute neighbors on rep X_glue
# InP: 0.62004662004662
# Compute neighbors on rep X_glue
# InS: 0.41361256544502617
# Compute neighbors on rep X_glue
# InV: 0.2162162162162162
# Compute neighbors on rep X_glue
# Mic: 0.12903225806451613
# Compute neighbors on rep X_glue
# OPC: 0.3595505617977528
# Compute neighbors on rep X_glue
# OliI: 0.12765957446808512
# Compute neighbors on rep X_glue
# OliM: 0.47257383966244726
# Compute neighbors on rep X_glue
# Peri: 0.018691588785046728

# %%
bio_df,bio=metric_res(df_list,name_list)
# bio_df['bio']=bio_df['bio'].round(2)
bio_df
# Out:
#                  ari       nmi  isolated_labels_aws  isolated_labels_f1  \
# d0lsi       0.508992  0.519643             0.495006            0.389231
# d0scbasset  0.494357  0.506489             0.492277            0.376441
# d1lsi       0.497484  0.510671             0.489629            0.398680
# d1scbasset  0.478119  0.479900             0.485255            0.370285
# d2lsi       0.466135  0.512497             0.490506            0.394963
# d2scbasset  0.459939  0.491656             0.489620            0.377819
# d3lsi       0.468682  0.516000             0.490721            0.390610
# d3scbasset  0.477159  0.513771             0.488654            0.386854
# d4lsi       0.478950  0.510671             0.490892            0.396530
# d4scbasset  0.459138  0.488449             0.488906            0.370330
# d5lsi       0.495349  0.511881             0.489536            0.384827
# d5scbasset  0.481988  0.489310             0.487962            0.364883
# d6lsi       0.430341  0.511299             0.490392            0.398253
# d6scbasset  0.493022  0.512938             0.485652            0.385914
# d7lsi       0.484839  0.518849             0.491022            0.393656
# d7scbasset  0.482626  0.490992             0.487603            0.375909
#
#             silhouette     clisi       bio
# d0lsi         0.503848  0.934718  0.558573
# d0scbasset    0.504690  0.936951  0.551867
# d1lsi         0.505613  0.923436  0.554252
# d1scbasset    0.507775  0.927841  0.541529
# d2lsi         0.506166  0.931708  0.550329
# d2scbasset    0.504823  0.932758  0.542769
# d3lsi         0.505368  0.932632  0.550669
# d3scbasset    0.508544  0.927582  0.550427
# d4lsi         0.502756  0.922696  0.550416
# d4scbasset    0.508885  0.927136  0.540474
# d5lsi         0.504038  0.920287  0.550986
# d5scbasset    0.507519  0.924732  0.542732
# d6lsi         0.502634  0.922382  0.542550
# d6scbasset    0.507354  0.935410  0.553382
# d7lsi         0.504791  0.932167  0.554221
# d7scbasset    0.507914  0.922702  0.544624

# %%
bio
# Out:
# <style type="text/css">
# #T_c342b_row0_col0, #T_c342b_row0_col1, #T_c342b_row0_col2, #T_c342b_row0_col6, #T_c342b_row1_col5, #T_c342b_row2_col3, #T_c342b_row9_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c342b_row0_col3, #T_c342b_row1_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_c342b_row0_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_c342b_row0_col5 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_c342b_row1_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_c342b_row1_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_c342b_row1_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_c342b_row1_col4 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_c342b_row1_col6 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_c342b_row2_col0, #T_c342b_row7_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_c342b_row2_col1, #T_c342b_row8_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_c342b_row2_col2, #T_c342b_row5_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_c342b_row2_col4 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_c342b_row2_col5 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c342b_row2_col6, #T_c342b_row6_col3, #T_c342b_row14_col6 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_c342b_row3_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_c342b_row3_col1, #T_c342b_row3_col2, #T_c342b_row9_col6, #T_c342b_row10_col5, #T_c342b_row11_col3, #T_c342b_row12_col0, #T_c342b_row12_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c342b_row3_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_c342b_row3_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_c342b_row3_col5, #T_c342b_row4_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c342b_row3_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_c342b_row4_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_c342b_row4_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_c342b_row4_col3 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_c342b_row4_col4, #T_c342b_row6_col6 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_c342b_row4_col5 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_c342b_row4_col6 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c342b_row5_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_c342b_row5_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_c342b_row5_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_c342b_row5_col4, #T_c342b_row7_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_c342b_row5_col5 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_c342b_row5_col6, #T_c342b_row12_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_c342b_row6_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c342b_row6_col1, #T_c342b_row13_col5 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_c342b_row6_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_c342b_row6_col4 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_c342b_row6_col5 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_c342b_row7_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_c342b_row7_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_c342b_row7_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_c342b_row7_col5, #T_c342b_row10_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_c342b_row7_col6, #T_c342b_row8_col6 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_c342b_row8_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_c342b_row8_col2, #T_c342b_row10_col6 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_c342b_row8_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_c342b_row8_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c342b_row8_col5, #T_c342b_row15_col5 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_c342b_row9_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_c342b_row9_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_c342b_row9_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c342b_row9_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_c342b_row9_col5 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_c342b_row10_col0 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_c342b_row10_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_c342b_row10_col3, #T_c342b_row14_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_c342b_row10_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_c342b_row11_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_c342b_row11_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_c342b_row11_col2, #T_c342b_row15_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_c342b_row11_col4 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_c342b_row11_col5 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_c342b_row11_col6 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_c342b_row12_col1 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_c342b_row12_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_c342b_row12_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_c342b_row12_col6 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_c342b_row13_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_c342b_row13_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_c342b_row13_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_c342b_row13_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_c342b_row13_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_c342b_row13_col6, #T_c342b_row14_col5 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_c342b_row14_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_c342b_row14_col1 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_c342b_row14_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_c342b_row14_col4 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_c342b_row15_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_c342b_row15_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_c342b_row15_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_c342b_row15_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_c342b_row15_col6 {
#   background-color: #cadef0;
#   color: #000000;
# }
# </style>
# <table id="T_c342b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c342b_level0_col0" class="col_heading level0 col0" >ari</th>
#       <th id="T_c342b_level0_col1" class="col_heading level0 col1" >nmi</th>
#       <th id="T_c342b_level0_col2" class="col_heading level0 col2" >isolated_labels_aws</th>
#       <th id="T_c342b_level0_col3" class="col_heading level0 col3" >isolated_labels_f1</th>
#       <th id="T_c342b_level0_col4" class="col_heading level0 col4" >silhouette</th>
#       <th id="T_c342b_level0_col5" class="col_heading level0 col5" >clisi</th>
#       <th id="T_c342b_level0_col6" class="col_heading level0 col6" >bio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c342b_level0_row0" class="row_heading level0 row0" >d0lsi</th>
#       <td id="T_c342b_row0_col0" class="data row0 col0" >0.508992</td>
#       <td id="T_c342b_row0_col1" class="data row0 col1" >0.519643</td>
#       <td id="T_c342b_row0_col2" class="data row0 col2" >0.495006</td>
#       <td id="T_c342b_row0_col3" class="data row0 col3" >0.389231</td>
#       <td id="T_c342b_row0_col4" class="data row0 col4" >0.503848</td>
#       <td id="T_c342b_row0_col5" class="data row0 col5" >0.934718</td>
#       <td id="T_c342b_row0_col6" class="data row0 col6" >0.558573</td>
#     </tr>
#     <tr>
#       <th id="T_c342b_level0_row1" class="row_heading level0 row1" >d0scbasset</th>
#       <td id="T_c342b_row1_col0" class="data row1 col0" >0.494357</td>
#       <td id="T_c342b_row1_col1" class="data row1 col1" >0.506489</td>
#       <td id="T_c342b_row1_col2" class="data row1 col2" >0.49

# %%
import os 
os.makedirs(path+'Results',exist_ok=True)

# %%
bio_df.to_csv(path+'Results/scb600bio.csv')

# %%
plt.figure(dpi=120)
f,ax=plt.subplots(figsize=(10,8))

sns.heatmap(data=bio_df,
           cmap=plt.get_cmap('Greens'),
           annot=True,
            #not_kws={'size':1},
            
           )

plt.title('scib metrics')
plt.xlabel('metric type')
plt.ylabel('modified models')
plt.savefig(path+'Results/scib_heatmap_600epochs.png',bbox_inches='tight')

# %%
data=bio_df['bio']
data=pd.DataFrame({'bio':data})
data_lsi = data.iloc[[0,2,4,6,8,10,12,14],:]
data_scb = data.iloc[[1,3,5,7,9,11,13,15],:]
from scipy import stats 
t_stat,pval=stats.ttest_ind(data_lsi['bio'],data_scb['bio'])
t_stat,pval #accept H0: two sample have similar distribution
# Out:
# (2.2732894057693787, 0.03928776587116591)

# %%
res_lsi=stats.normaltest(data_lsi)
print(res_lsi.pvalue)
res_scb=stats.normaltest(data_scb)
print(res_scb.pvalue)
# Out:
# [0.29621311]
# [0.26381879]
# /home/ubuntu0/miniconda3/envs/glue2_scib/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
